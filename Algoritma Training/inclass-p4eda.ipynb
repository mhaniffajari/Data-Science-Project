# %% [markdown]
# **Inclass: Python for Exploratory Data Analysis**
#
# - Part of Comprehensive Data Science and Machine Learning for PT Freeport
# - Course Length: 15 Hours
# - Last Updated: September 2025
# ___
#
# - Developed by [Algoritma](https://algorit.ma)'s product division and instructor team

# %%
import pandas as pd
pd.options.display.float_format = '{:.2f}'.format

# %% [markdown]
# # Training Objectives
#
# - **Module 1 : Python Programming**
#     - Introduction to Object Oriented Programming Concepts
#         + Encapsulation
#         + Inheritance
#         + Polymorphism
#         + Abstraction
#     - Python Flow Control
#         + Using if-else statement
#         + Defining and calling functions
#     - OOP principle applications
# - **Module 2: Introduction to Dataframes**
#     - Reading data
#         + From .csv format
#     - Python data types
#     - Data frame structure
# - **Module 3: Working with Datetime and Category**
#     - Working with datetime data
#     - Working with categorical data
# - **Module 4: Indexing and subsetting in pandas**
#     - Slicing dataframes
#     - Conditional subsetting
# - **Module 5: Frequency tables in Pandas**
#     - Data aggregation
# - **Module 6: Dealing with untidy data**
#     - Missing values treatment
#     - Removing duplicates value
# - **Module 7: Dealing with text data**
#     - Regular expressions and their role in text processing
#     - Regex patterns for text matching and extraction

# %% [markdown]
# # 1. Pengenalan Jupyter Notebook

# %% [markdown]
# File yang sedang kita gunakan ini disebut dengan **notebook**.
#
# > 📓 **Notebook** merupakan file Python dengan format `.ipynb` yang memungkinkan kita untuk menulis kode Python dan memberikan penjelasan secara interaktif.

# %% [markdown]
# ## Type of Cells

# %% [markdown]
# ### ✨ Markdown

# %% [markdown]
# > **Markdown** merupakan cell yang yang digunakan untuk menuliskan narasi pada file notebook.
#
# Pada markdown, kita dapat membuat hal-hal berikut.
#
# 1. **Heading**
#
#    Untuk membuat heading, kita dapat menambahkan hashtag/tanda pagar (`#`).
#    - `#`: untuk membuat heading 1.
#    - `##`: untuk membuat heading 2.
#    - `###`: untuk membuat heading 3.
#
# 2. **Emphasis**
#
#    Untuk membuat teks dengan karakter yang lebih tegas, kita dapat menambahkan tanda bintang (`*`).
#    - *kata*: untuk mengatur tulisan menjadi italic.
#    - **kata**: untuk mengatur tulisan menjadi bold.
#    - ***kata***: untuk mengatur tulisan menjadi italic & bold.
#
# 3. **Numbering & Bullets**
#
#    Untuk membuat beberapa point, terdapat beberapa metode yang bisa digunakan.
#    * Untuk membuat point dalam bentuk angka, bisa menggunakan angka: 1, 2, 3, dst.
#    * Untuk membuat point dalam bentuk bullets, bisa menggunakan `-` atau `*`.
#
# 4. **Persamaan Matematika**
#
#     - Contoh:
#     \begin{equation}
#     x = \frac{-b \pm \sqrt{b^{2}-4ac}}{2a}
#     \end{equation}
#     - Penulisan formula matematika pada markdown menggunakan LaTeX.

# %% [markdown]
# ### ✨ Code

# %% [markdown]
# > 💻 **Code** merupakan cell yang yang digunakan untuk menuliskan kode Python pada file notebook.

# %% [markdown]
# Pada saat kita menjalankan code cell, akan dikeluarkan output sesuai dengan kode yang dituliskan. Baris yang diawali dengan tanda pagar (`#`) tidak akan dieksekusi.

# %%
# ini adalah contoh code cell
# ini adalah komentar, tidak akan dieksekusi
# contoh: menampilkan teks

# %%
# contoh: operasi matematika

# %% [markdown]
# Perhatikan bahwa setiap kita menjalankan code cell, akan ada angka yang menunjukkan urutan eksekusi kode. Urutan ini dapat kita manfaatkan untuk tracking alur kode dan mendeteksi apabila terdapat kesalahan pada program.

# %% [markdown]
# ## Cell Mode

# %% [markdown]
# Terdapat 2 mode cell dalam notebook:
#
# 1. **Command Mode**
#
#     - Pada command mode, warna cell akan lebih gelap.
#     - Shortcut:
#         - `a` : menambah cell baru di atas.
#         - `b` : menambah cell baru di bawah.
#         - `d` + `d` : menghapus cell terpilih.
#         - `c` : menyalin cell terpilih.
#         - `v` : paste cell terpilih.
#         - `m` : mengubah tipe cell ke markdown.
#         - `y` : mengubah tipe cell ke kode.
#         - `enter` : enter edit mode.
#
# 3. **Edit Mode**
#
#     - Pada edit mode, warna cell akan lebih terang.
#     - Shortcut:
#         - `Ctrl + Enter`: eksekusi satu cell.
#         - `Esc`: mengubah edit mode menjadi command mode.

# %% [markdown]
# # 2. Python Programming
#
# ## 1️⃣ Python Object Oriented Programming
#
# ### 🟢 **Building Blocks OOP**

# %% [markdown]
# ### Variables/Attributes

# %% [markdown]
# Saat menggunakan Python, sebagian besar pekerjaan kita akan melibatkan **variabel**.
#
# > **Variabel** merupakan tempat untuk menyimpan sebuah nilai.
#
# Untuk menyimpan nilai ke sebuah variabel, kita menggunakan assignment operator (`=`).

# %%
# melakukan assignment
nama = 'Hanif'

# %%
# menampilkan isi sebuah variabel
nama
# Out:
# 'Hanif'

# %% [markdown]
# ### Function/Method
#
# Sebuah fungsi berguna untuk mengelompokkan sekumpulan baris kode sehingga dapat dijalankan lebih dari satu kali. Fungsi memungkinkan kita untuk tidak perlu berulang kali menulis kode yang sama. Cara pembuatan fungsi adalah sebagai berikut
#
# ```python
# def name_fungsi(argumen):
#     # Kumpulan baris kode
# ```
#
# 📌 [Python Defining Function Official Documentation](https://docs.python.org/3/tutorial/controlflow.html#defining-functions)

# %% [markdown]
# Membuat function untuk variable `nama`

# %%
#code here

def menampilkan_nama():
    return nama

# %%
menampilkan_nama()
# Out:
# 'Hanif'

# %%
def menampilkan_nama(nama_belakang):
    return nama + ' ' + nama_belakang

# %% [markdown]
# 💡 Contoh lain penerapan `function` : Misalnya kita ingin membuat fungsi untuk melakukan perkalian dua angka

# %%
#code here
def perkalian (a,b):
    return a * b

perkalian(3,4)
# Out:
# 12

# %% [markdown]
# ✅ **Highlight Point:**
#
# Disebut **attributes** dan **methods** hanya kalau berada dalam `Class`. Apabila di luar `Class` disebut **variables** dan **functions**.

# %% [markdown]
# ### 🟢 **Key Concepts OOP**
#
# ### Encapsulation
#
# **Encapsulation** adalah menyatukan *atributes* dan *method* dalam satu paket, yang disebut `class`. Bayangkan seperti sebuah **kapsul**: semua yang dibutuhkan sebuah object untuk mendeskripsikan dirinya dan melakukan tindakannya disimpan di dalam kapsul tersebut. Dunia luar tidak perlu tahu bagaimana cara kerja di dalam kapsul, cukup menggunakan metode (`methods`) yang sudah disediakan. Hal ini membantu menjaga data tetap aman dan memastikan data hanya bisa diubah dengan cara yang terkontrol
#
# <p align="center">
#   <img src="assets/encapsulation.png" width="400">
# </p>
#
#
# **Contoh :** Membuat *encapsulation* pada class `Employee`

# %% [markdown]
# 1. Definisi `Class`
#     - **Attributes** : name, position, salary
#     - **Method** :
#         + `get_info()` -> menampilkan informasi nama, divisi dan salary employee
#         + `get_salary()` -> menampilkan informasi gaji

# %%
# Definisi nama kelas
class Employee:
    def __init__(self, nama:str, position: str, salary: float):
        self.nama = nama
        self.position = position
        self.salary = salary
# Definisi Attributes

# Definisi Method
    def get_info(self):
        return f"Nama: {self.nama}, Position: {self.position}, Salary: {self.salary}"
    def get_salary(self):
        return f"salary : {self.salary}"

# %%
hanif = Employee('Hanif','DE','hanif')
hanif.get_info()
hanif.get_salary()
# Out:
# 'salary : hanif'

# %%
hanif.nama
# Out:
# 'Hanif'

# %% [markdown]
# ✅ **Highlight Point:**
#
# - `__init__` dalam Python adalah konstruktor, yaitu fungsi khusus yang otomatis dijalankan ketika sebuah objek baru dibuat dari sebuah class. Fungsinya adalah untuk menginisialisasi atribut dari objek tersebut, sehingga setiap objek punya data awal yang jelas dan konsisten.

# %% [markdown]
# 2. Memanfaatkan `Class` dengan mendefinisikan `attributes` dan `methods`

# %%
# code here
emp = Employee('Budi','Data Analyst',80000)
emp.get_info()
# Out:
# 'Nama: Budi, Position: Data Analyst, Salary: 80000'

# %%
emp.get_salary()
# Out:
# 'salary : 80000'

# %%
class BankAccount:
    def __init__(self,owner,balance):
        self.owner = owner
        self.__balance = balance
    def get_balance(self):
        return self.__balance

# %%
account = BankAccount('Hanif',100000)
account.get_balance()
# Out:
# 100000

# %% [markdown]
# ### Inheritance
#
# **Inheritance** memungkinkan kita untuk membuat class baru, seperti `Manager`, yang secara otomatis mewarisi atribut dan metode dari `Employee`, sekaligus dapat menambahkan perilaku baru miliknya sendiri.
#
# <p align="center">
#   <img src="assets/inheritance.png" width="400">
# </p>

# %% [markdown]
# 1. Definisi child `Class` **Manager**
#     - Menambah atribut `team_size`
#     - Menambah method `manage_team()`

# %%
# Copy & paste class employee
# Definisi nama kelas
class Employee:
    def __init__(self, nama:str, position: str, salary: float):
        self.nama = nama
        self.position = position
        self.salary = salary
# Definisi Attributes

# Definisi Method
    def get_info(self):
        return f"Nama: {self.nama}, Position: {self.position}, Salary: {self.salary}"
    def get_salary(self):
        return f"salary : {self.salary}"

# Definisi nama kelas child Manager
class Manager(Employee):
# Definisi Attributes
    def __init__(self, nama, position, salary, team_size):
        super().__init__(nama, position, salary)
        self.team_size = team_size
# Definisi Method
    def manage_team(self):
        return f"{self.nama} memanage tim yang berjumlah {self.team_size} orang."

# %% [markdown]
# ✅ **Highlight Point:**
#
# - `super` adalah fungsi bawaan Python yang dipakai untuk memanggil method dari parent class

# %% [markdown]
# 2. Memanfaatkan `Class` **Manager** dengan mendefinisikan `attributes` dan `methods`

# %%
manager_a = Manager("Leon","Data Manager",15000000,20)

# %%
manager_a.get_info()
# Out:
# 'Nama: Leon, Position: Data Manager, Salary: 15000000'

# %%
manager_a.get_salary()
# Out:
# 'salary : 15000000'

# %%
manager_a.manage_team()
# Out:
# 'Leon memanage tim yang berjumlah 20 orang.'

# %% [markdown]
# ### Polymorphism
#
# Setelah memahami konsep inheritance, kita tahu bahwa sebuah class turunan dapat mewarisi atribut dan method dari class induknya. Namun, dalam praktik dunia nyata, tidak semua objek turunan akan memiliki perilaku yang sama persis dengan induknya.
#
# Di sinilah muncul konsep **polymorphism**. Secara sederhana, polymorphism memungkinkan **satu nama method yang sama memiliki perilaku berbeda**, tergantung pada objek yang memanggilnya.
#
# 📌 **Contoh di gaji (`get_salary()`)**: Semua karyawan pasti memiliki gaji. Namun setiap posisi tentunya memiliki proporsi gaji masing-masing sesuai dengan jabatan dan responsibilitynya. Misal :
#
#  - **Staff** → gaji pokok bulanan.
#  - **Manager** → gaji pokok + tunjangan kepemimpinan.
#  - **Intern** → mungkin hanya uang transport atau insentif kecil.
#
#  Mari kita membuat *method* `get_salary()` pada class `Manager` dengan kondisi salary yang diperoleh adalah : Gaji Pokok + Tunjangan Kepemimpinan. Dimana tunjangan kepemimpinan diperoleh dengan mengkalikan jumlah *team_size* dengan Rp 200.000 (team_size * 200000).

# %% [markdown]
# 1. Definisi fungsi baru

# %%
# code here
class Manager(Employee):
# Definisi Attributes
    def __init__(self, nama, position, salary, team_size):
        super().__init__(nama, position, salary)
        self.team_size = team_size
# Definisi Method
    def manage_team(self):
        return f"{self.nama} memanage tim yang berjumlah {self.team_size} orang."
    def get_salary(self):
        if self.position == 'Manager':
                final_salary = self.salary + self.team_size + 5000
        return final_salary

# %%
# code here
class Staff(Employee):
# Definisi Attributes
    def __init__(self, nama, position, salary):
        super().__init__(nama, position, salary)
# Definisi Method
    def get_salary(self,overtime=0):
        if self.position == 'Staff':
                final_salary =  self.salary + (50000 * overtime)
        elif self.position == 'Intern':
                final_salary = 2000
        return final_salary

# %% [markdown]
# 2. Memanggil fungsi `get_salary()` dari class `Manager`

# %%
manager = Manager('Siti','Manager',150000,10)
manager.get_salary()
# Out:
# 155010

# %%
staff = Staff('Almond','Staff',10000)
staff.get_salary(8)
# Out:
# 410000

# %% [markdown]
# ### Abstraction
#
# Dalam OOP, abstraction artinya kita hanya menampilkan apa yang bisa dilakukan (interface) tanpa menunjukkan bagaimana cara melakukannya (implementasi detail). Kita cukup tahu “apa yang harus ada” di suatu class, tapi detail pelaksanaannya diserahkan ke turunan (`child` class)

# %% [markdown]
# 1. Definisi class `Employee` dengan *abstraction* method `work()`

# %%
# code here
from abc import ABC, abstractmethod
class Employee(ABC):
    def __init__(self, nama:str, position: str, salary: float):
        self.nama = nama
        self.position = position
        self.salary = salary
# Definisi Attributes

# Definisi Method
    def get_info(self):
        return f"Nama: {self.nama}, Position: {self.position}, Salary: {self.salary}"
    def get_salary(self):
        return f"salary : {self.salary}"
    @abstractmethod
    def work(self):
        pass

# %% [markdown]
# 2. Definisi child class `Manager` dengan tambahan method `work()`

# %%
# code here
# code here
class Manager(Employee):
# Definisi Attributes
    def __init__(self, nama, position, salary, team_size):
        super().__init__(nama, position, salary)
        self.team_size = team_size
# Definisi Method
    def manage_team(self):
        return f"{self.nama} memanage tim yang berjumlah {self.team_size} orang."
    def get_salary(self):
        if self.position == 'Manager':
                final_salary = self.salary + self.team_size + 5000
        return final_salary
    def work(self):
        return f"{self.nama} is reporting to director."

# %% [markdown]
# 3. Definisi child class `Intern` dengan tambahan method `work()`

# %%
# code here
class Intern(Employee):
    def __init__(self, nama, position,salary, university):
        super().__init__(nama, position,salary)
        self.university = university
    def work(self):
        return f"{self.nama} is intern student from {self.university}."
    def get_salary(self):
        return 2000

# %% [markdown]
# 4. Menampilkan output

# %%
# code here
intern_a = Intern('Rina','Intern',10000,'UI')
intern_a.work()
# Out:
# 'Rina is intern student from UI.'

# %% [markdown]
# ## 2️⃣Python Control Flow

# %% [markdown]
# ### `if` and `else` Statements
#
# Konsep dari else if python terbilang cukup sederhana, yaitu komputer akan mengeksekusi sesuatu berdasarkan apa yang sebelumnya kita instruksikan dalam komputer. Premis yang digunakan dalam else if python adalah premis jika-maka. Sebagai contoh, "jika" nilai seorang siswa lebih atau sama dengan 80, "maka" siswa akan mendapat predikat A. Dalam else if python, jika kondisi yang diinstruksikan telah terpenuhi maka ia akan menampilkan output A dan jika kondisi tidak terpenuhi maka ia akan menampilkan output B
#
# - **Kondisi if**
# Kondisi if merupakan hal mendasar dalam percabangan python. Pada kondisi if, digunakan untuk mengeksekusi sesuai kondisi yang terjadi. If merupakan kondisi utama dengan struktur sebagai berikut:
#
# ```
#  if kondisi:
#     statements()
# ```
# Pada kondisi diisi dengan variabel atau nilai. Jika kondisi bernilai benar, maka statements() akan dieksekusi oleh sistem. Jika kondisi if tidak bernilai benar, maka statements() pun tidak memberikan output apa-apa.
#
# - **Kondisi if else**
#
# Jika pada bagian sebelumnya telah dikenalkan mengenai fungsi if, maka fungsi kelanjutannya adalah fungsi if else. Pada fungsi if else tidak hanya mengeksekusi kondisi jika bernilai benar saja, akan tetapi juga mengeksekusi kondisi jika bernilai salah. Penerapannya dalam pengkondisian antara lain, pernyataan yang bernilai benar akan dieksekusi sesuai statement yang ada pada kode dalam 'if', sedangkan pernyataan yang bernilai salah akan dieksekusi sesuai statement yang ada pada kode dalam 'else' .
#
# Berikut adalah contoh dari hasil pemanfaatan kedua statement tersebut:
#
# ```python
# if case1:
#     perform action1
# elif case2:
#     perform action2
# else:
#     perform action3
# ```
#
# 📌 [Python `if else` Official Documentation](https://docs.python.org/3/reference/compound_stmts.html#if)

# %%
# Contoh kondisi if terpenuhi

# Input


# Kondisi

# %% [markdown]
# 🏄‍♀️ ***Dive Deeper (5 menit)***
#
# Di tambang emas Freeport, salah satu tantangan utama adalah pengelolaan air tanah (dewatering) agar tidak mengganggu operasi penambangan. Berdasarkan hasil uji permeabilitas batuan (Q, dalam milidarcy), engineer perlu menentukan metode dewatering yang tepat.
#
# Aturan pengambilan keputusan:
# - Jika Q > 0.001 mD, maka batuan sangat permeabel → gunakan **high-capacity pump system**
# - Jika 0.00001 ≤ Q ≤ 0.001 mD, maka batuan berpermeabilitas sedang → gunakan **standard pumping**
# - Jika Q < 0.00001 mD, maka batuan hampir kedap air → cukup gunakan **monitoring well** untuk mengontrol air.
#
# Untuk saat ini diketahui permeabilitas batuan sebesar 0.0005 milidarcy. Metode dewatering apakah yang paling sesuai?

# %%
#code here
permaibility_value = 0.00001
def pump_system_selector(permaibility_value):
    if permaibility_value < 0.001:
        pump_system = "high_capacity"
    elif permaibility_value >= 0.00001 and permaibility_value <= 0.01:
        pump_system = "standard_capacity"
    else:
        pump_system = "monitoring_well"
    return pump_system

pump_system_selector(permaibility_value)
# Out:
# 'high_capacity'

# %% [markdown]
# ## 3️⃣ Python Data Types

# %% [markdown]
# ### 🔠 String
#
# Python mewakili string apapun sebagai object `str`. Adapun beberapa cara untuk membuat nilai string:
#
# - menggunakan `''` (contoh: `'Jakarta'` atau `'saya lahir di Bekasi'`)
# - mengunakan `""` (contoh: `"hari jum'at"`)
# - menggunakan `'''` atau `"""` (contoh: `'''Dia bersorak "Hore! Sudah hari Jum'at"'''`)

# %%
#code here

kota = 'tebet'

# %% [markdown]
# Kita dapat melakukan pengecekan tipe data dengan menggunakan fungsi `type()`, seperti yang akan dituliskan di bawah ini.

# %%
#code here
type(kota)
# Out:
# str

# %% [markdown]
# ### 🔢 Number
#
# Untuk menyimpan number, python memiliki dua tipe data asli yang disebut `int` dan `float`.
# - `int` digunakan untuk menyimpan **bilangan bulat** (yaitu: 1,2,-3)
# - `float` digunakan untuk menyimpan **bilangan real** (yaitu: 0.7, -1.8, -1000.0)

# %%
#code here

# %% [markdown]
# ### 🗃️ List
#
# `list` digunakan untuk menyimpan beberapa nilai dalam python. Untuk membuatnya, cukup letakan nilai di dalam tanda kurung siku `[]`

# %%
#code here
customer = ['hanif','leo','ronaldo']

# %% [markdown]
# **✨ Operasi List ✨**
#
# - `list_x[i]`: Mengakses elemen ke-i dari `list_x` (zero-based indexing).
# - `list_x.append(a)`: Menambahkan `a` ke dalam `list_x`.
# - `list_x.remove(a)`: Menghapus nilai `a` dari `list_x`.

# %%
#code here

# %% [markdown]
# ## 4️⃣ Python Behaviour

# %% [markdown]
# ### Case-Sensitive

# %% [markdown]
# Python adalah bahasa pemrograman yang **case-sensitive**. Kata `'freeport'` tidak sama dengan `'FREEPORT'`. Pada kode di bawah ini, kita menggunakan operator `==` untuk membandingkan kesetaraan kedua nilai tersebut.

# %%
# code here

# %% [markdown]
# > ℹ️ Output dari kode di atas adalah `False`. Hal ini menandakan kedua nilai tersebut berbeda.

# %% [markdown]
# Begitu juga dengan penamaan variabel: `perusahaan` tidak sama dengan `Perusahaan`.

# %%
# perusahaan == Perusahaan

# %% [markdown]
# ### Keywords

# %% [markdown]
# > **Keywords** adalah kata kunci yang sudah ditetapkan oleh Python sebagai nama yang tidak bisa dipakai baik untuk penamaan fungsi, variabel, dan lainnya.

# %% [markdown]
# Berikut adalah daftar keywords yang sudah digunakan Python.

# %%
import keyword

keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %% [markdown]
# ### Python Variable Do's & Don'ts

# %% [markdown]
# ⚠️ Berikut beberapa ketentuan dalam memberikan nama variabel pada Python.
#
# - Tidak boleh menggunakan angka di awal. Misalnya, `1Algoritma`.
# - Hanya kombinasi dari huruf kapital (A-Z), huruf nomina (a-z), angka (0-9).
# - Special character `!, $ , &, dll` tidak dapat digunakan dalam penamaan variabel.
# - Bersifat case-sensitive sehingga penamaan variabel `algoritma`, `ALGORITMA`, dan `Algoritma` adalah 3 variabel yang berbeda.
# - Tidak boleh menggunakan keywords pada Python.

# %% [markdown]
# # 3. `pandas` Library & Dataframe

# %% [markdown]
# Salah satu kelebihan Python adalah tersedianya banyak **package** atau **library** yang dapat kita gunakan dengan mudah.
#
# > 📚 **Package** atau **library** sebagai sekumpulan fungsi/program yang telah ditulis orang lain dan dapat kita gunakan kembali.
#
# Salah satu library yang akan digunakan pada course ini adalah **`pandas`**.
#
# 🐼 **`pandas`** adalah library Python yang sangat populer untuk analisis data. Library ini mendukung berbagai format data seperti CSV dan XLSX. Dengan `pandas`, Anda dapat melakukan berbagai operasi untuk menghasilkan analisis yang meaningful.
#
# > 📌 Selengkapnya mengenai `pandas`: [dokumentasi `pandas`](https://pandas.pydata.org/docs/index.html).

# %% [markdown]
# ## Import `pandas`

# %% [markdown]
# Untuk dapat menggunakan library, kita perlu meng-import library tersebut terlebih dahulu.

# %%
# meng-import pandas dengan aliasing
import pandas as pd

# %% [markdown]
# Setelah menggunakan aliasing, kita cukup memanggil library dengan nama aliasnya, bukan nama aslinya.

# %%
# melihat versi pandas dengan aliasing
pd.__version__
# Out:
# '2.0.0'

# %% [markdown]
# ## Reading Data from CSV Format

# %% [markdown]
# Salah satu format sumber data yang dapat dibaca oleh `pandas` adalah format CSV. Untuk membaca file CSV, kita menggunakan fungsi `read.csv()` dari `pandas` dan memasukkan direktori dari file yang ingin dibaca.

# %% [markdown]
# <div style="background-color:#90EE90; padding: 3px; border-radius: 5px; border: 2px solid #000000;">
#
# ```python
# # sintaks untuk menggunakan fungsi-fungsi pada pandas
# pd.function_name()
# ```
#
# </div>

# %% [markdown]
# Silakan baca data `equipment.csv` yang terdapat pada folder `data_input`.

# %%
# simpan data ke variabel equipment
equipment = pd.read_csv('data_input/equipment.csv')
equipment.head()
# Out:
#        ID        DATE  MAINTENANCE_VENDOR         MANUFACTURER   S15    S17
# 0  100001  2014-12-02  Optimech Solutions  Yokentra Industries 11.09 145.22  \
# 1  100001  2014-12-03  Optimech Solutions  Yokentra Industries  8.88 187.57
# 2  100001  2014-12-04  Optimech Solutions  Yokentra Industries  8.68 148.36
# 3  100001  2014-12-05  Optimech Solutions  Yokentra Industries  9.99 133.66
# 4  100001  2014-12-06  Optimech Solutions  Yokentra Industries  8.48 197.18
#
#    S16  AGE_OF_EQUIPMENT  FAILURE_TARGET
# 0 8.43               880               0
# 1 6.48               881               0
# 2 6.16               882               0
# 3 9.32               883               0
# 4 8.02               884               0

# %% [markdown]
# Dataset `equipment` ini merupakan data dummy yang memuat informasi tentang kegagalam mesin dalam beroperasi
#
# **💡 Deskripsi Data**
#
# - `ID`: ID yang merepresentasikan mesin tertentu.
# - `DATE`: Tanggal pengamatan
# - `MAINTENANCE_VENDOR`: Perusahaan atau tim yang bertanggung jawab atas pemeliharaan.
# - `MANUFACTURER`: Produsen peralatan.
# - `S15`: Sensor 15
# - `S17`: Sensor 17
# - `S16`: Sensor 16
# - `AGE_OF_EQUIPMENT`: Usia mesin, dalam hari.
# - `FAILURE_TARGET`: Kegagalan mesin, 1 adalah kegagalan, 0 bukan kegagalan.

# %% [markdown]
# 📌 **Additional Information**
#
# - Python menggunakan sistem **zero based indexing**. Urutan pada Python dimulai dari angka 0.
# - Terdapat beberapa parameter dalam fungsi `.read_csv()`. Dokumentasi selengkapnya ada [di sini](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_csv.html)

# %% [markdown]
# ### Series
#
# **Dataframe** terdiri dari atas beberapa **Series** (mengacu pada satu kolom). Satu series harus berisi data dengan tipe data yang sama.
#
# Untuk mengakses sebuah series/kolom, kita dapat menggunakan kurung siku (`[]`) :
#
# ```python
# dataframe['nama_kolom']
# ```

# %%
equipment.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 307751 entries, 0 to 307750
# Data columns (total 9 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   ID                  307751 non-null  int64
#  1   DATE                307751 non-null  object
#  2   MAINTENANCE_VENDOR  307751 non-null  object
#  3   MANUFACTURER        307751 non-null  object
#  4   S15                 307751 non-null  float64
#  5   S17                 307751 non-null  float64
#  6   S16                 307751 non-null  float64
#  7   AGE_OF_EQUIPMENT    307751 non-null  int64
#  8   FAILURE_TARGET      307751 non-null  int64
# dtypes: float64(3), int64(3), object(3)
# memory usage: 21.1+ MB

# %%
# code here
print(equipment['MANUFACTURER'].unique())
# Out:
# ['Yokentra Industries' 'Rivatek Manufacturing' 'Trimech Industries'
#  'Steelon Industries' 'Wahana Teknikindo' 'Xelora Manufacturing'
#  'Ultimech Industries' 'Quantum Forge' 'Vortek Industries'
#  'Zentron Manufacturing']

# %% [markdown]
# `pandas` akan menentukan tipe data dari masing-masing Series secara otomatis, namun hasil penentuan `pandas` tidak selalu benar. Maka, kita perlu mengecek tipe data pada dataframe yang telah dibaca.

# %% [markdown]
# ## Common Initial Checking Operations

# %% [markdown]
# <div class="alert-warning alert" style="text-align: center; margin: 0 auto; color: black;">
#
# Salah satu best practice sebelum melakukan analisis data adalah **melakukan initial checking** untuk memastikan data sudah bersih. Jika belum, perlu dilakukan penyesuaian agar data memiliki format yang benar sehingga analisis dapat memberikan hasil yang akurat dan reliable.
#
# </div>

# %% [markdown]
# Berikut adalah beberapa method/atribut yang umum dimanfaatkan untuk initial checking pada data.

# %% [markdown]
# * `.head()`: menampilkan n data teratas pada dataframe. Default-nya menampilkan 5 data teratas.

# %%
# menampilkan 3 data teratas 
equipment.head(3)
# Out:
#        ID        DATE  MAINTENANCE_VENDOR         MANUFACTURER   S15    S17
# 0  100001  2014-12-02  Optimech Solutions  Yokentra Industries 11.09 145.22  \
# 1  100001  2014-12-03  Optimech Solutions  Yokentra Industries  8.88 187.57
# 2  100001  2014-12-04  Optimech Solutions  Yokentra Industries  8.68 148.36
#
#    S16  AGE_OF_EQUIPMENT  FAILURE_TARGET
# 0 8.43               880               0
# 1 6.48               881               0
# 2 6.16               882               0

# %% [markdown]
# * `dtypes`: menampilkan tipe data yang dimiliki oleh setiap kolom.

# %%
# tipe data setiap kolom dataframe equipment
equipment.dtypes
# Out:
# ID                      int64
# DATE                   object
# MAINTENANCE_VENDOR     object
# MANUFACTURER           object
# S15                   float64
# S17                   float64
# S16                   float64
# AGE_OF_EQUIPMENT        int64
# FAILURE_TARGET          int64
# dtype: object

# %% [markdown]
# * `.info()`: menampilkan informasi tentang dataframe.

# %%
# informasi dataframe equipment
equipment.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 307751 entries, 0 to 307750
# Data columns (total 9 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   ID                  307751 non-null  int64
#  1   DATE                307751 non-null  object
#  2   MAINTENANCE_VENDOR  307751 non-null  object
#  3   MANUFACTURER        307751 non-null  object
#  4   S15                 307751 non-null  float64
#  5   S17                 307751 non-null  float64
#  6   S16                 307751 non-null  float64
#  7   AGE_OF_EQUIPMENT    307751 non-null  int64
#  8   FAILURE_TARGET      307751 non-null  int64
# dtypes: float64(3), int64(3), object(3)
# memory usage: 21.1+ MB

# %% [markdown]
# * `describe()`: menampilkan informasi statistik setiap kolom dataframe.

# %%
# informasi statistik kolom numerik pada dataframe equipment
equipment.describe()
# Out:
#              ID       S15       S17       S16  AGE_OF_EQUIPMENT
# count 307751.00 307751.00 307751.00 307751.00         307751.00  \
# mean  100310.83     14.59     80.27      7.97           2524.19
# std      177.57      8.82     85.80      2.32           3158.93
# min   100001.00      0.00      0.00      0.00              0.00
# 25%   100161.00      7.69      0.00      6.62            721.00
# 50%   100311.00     11.66     31.68      8.00           1113.00
# 75%   100467.00     22.56    160.08      9.46           2784.00
# max   100617.00     59.04   2555.52     24.60          15170.00
#
#        FAILURE_TARGET
# count       307751.00
# mean             0.04
# std              0.19
# min              0.00
# 25%              0.00
# 50%              0.00
# 75%              0.00
# max              1.00

# %% [markdown]
# ❓Bagaimana menampilkan ringkasan statistik untuk kolom selain numerik?

# %%
# code here
equipment.describe(include='object')
# Out:
#               DATE    MAINTENANCE_VENDOR        MANUFACTURER
# count       307751                307751              307751
# unique         731                     8                  10
# top     2014-12-02  Jetronix Maintenance  Trimech Industries
# freq           421                 42398               43129

# %% [markdown]
# ---<span style="background-color:#DFF2BF; padding: 10px; border-radius: 5px; display: block;">
#
# **💡 Perbedaan `()` dan `[]`**
#
# - `( )` digunakan untuk fungsi, memasukkan input pada fungsi.
# - `[ ]` digunakan untuk mengambil sebagian dari data (subsetting).
#
# **💡 Perbedaan Atribut dan Method/Function**
#
# - Atribut biasanya tidak menggunakan kurung `( )` dan output-nya tidak bisa diubah.
#   - Contoh: `.shape`.
# - Method/function biasanya menggunakan kurung `( )` dan output-nya bisa diatur.
#   - Contoh: `.head()`, `.info()`.
#
# </span>

# %% [markdown]
# ## `pandas` Data Types

# %% [markdown]
# <div class="alert-warning alert" style="text-align: center; margin: 0 auto; color: black;">
#
# Saat membaca data dengan `pandas`, library ini secara otomatis menentukan tipe data untuk setiap kolom. Namun, sering kali tipe data yang di-assign tidak sesuai sehingga perlu **diubah** secara manual untuk memastikan analisis berjalan dengan benar.
# </div>

# %% [markdown]
# ## Numeric, Object, and Category Types

# %% [markdown]
# ### Tipe Data Numerik
#
# * Tipe data untuk bilangan bulat: `int64`.
# * Tipe data untuk bilangan berkoma: `float64`.

# %%
# menampilkan tipe data dengan dtypes
equipment.dtypes
# Out:
# ID                      int64
# DATE                   object
# MAINTENANCE_VENDOR     object
# MANUFACTURER           object
# S15                   float64
# S17                   float64
# S16                   float64
# AGE_OF_EQUIPMENT        int64
# FAILURE_TARGET          int64
# dtype: object

# %% [markdown]
# ### Object dan Category
# Tipe data object (`object`) dan category (`category`) umumnya digunakan untuk data berupa kata/string.

# %% [markdown]
# <span style="background-color:#DFF2BF; padding: 10px; border-radius: 5px; display: block;">
#
# **💡 Kapan menggunakan `object` atau `category`?**
#
# - Saat terdapat banyak variasi nilai dalam 1 kolom: gunakan `object`.
# - Saat terdapat sedikit variasi nilai dalam 1 kolom: gunakan `category`.
#
# **💡 Mengapa perlu mengubah `object` menjadi `category`?**
#
# - **Business Perspective Side**: dapat memandu seorang analyst untuk memilih metode statistik atau jenis visualisasi yang digunakan untuk mengolah data.
# - **Technical Side**: tipe data categorical akan menghemat memori dan menambah kecepatan komputasional
#
# </span>

# %% [markdown]
# Untuk mengetahui kolom mana yang bisa diubah menjadi `category`, gunakan fungsi `.nunique()` atau `.unique()`.

# %% [markdown]
# * `.nunique()`: melihat banyak nilai unique pada dataframe/series.

# %%
# banyak nilai unique pada setiap kolom dataframe equipment
equipment.nunique()
# Out:
# ID                      421
# DATE                    731
# MAINTENANCE_VENDOR        8
# MANUFACTURER             10
# S15                   27139
# S17                   13376
# S16                   31575
# AGE_OF_EQUIPMENT      14322
# FAILURE_TARGET            2
# dtype: int64

# %% [markdown]
# * `.unique()`: melihat nilai unique pada series.

# %%
# melihat nilai unique kolom maintenance_vendor dan manufacturer
equipment['MAINTENANCE_VENDOR'].unique()
equipment['MANUFACTURER'].unique()
# Out:
# array(['Yokentra Industries', 'Rivatek Manufacturing',
#        'Trimech Industries', 'Steelon Industries', 'Wahana Teknikindo',
#        'Xelora Manufacturing', 'Ultimech Industries', 'Quantum Forge',
#        'Vortek Industries', 'Zentron Manufacturing'], dtype=object)

# %% [markdown]
# Mari kita lihat kembali tipe data setiap kolom pada `equipment`.

# %%
# code here
equipment.dtypes
# Out:
# ID                      int64
# DATE                   object
# MAINTENANCE_VENDOR     object
# MANUFACTURER           object
# S15                   float64
# S17                   float64
# S16                   float64
# AGE_OF_EQUIPMENT        int64
# FAILURE_TARGET          int64
# dtype: object

# %% [markdown]
# ❓ Kolom mana yang tipe datanya dapat diubah menjadi `category`?

# %% [markdown]
# Untuk mengganti tipe data, kita dapat menggunakan fungsi `.astype()`:
# ```python
# # mengubah tipe data kolom
# dataframe_name['column_name'] =  dataframe_name['column_name'].astype('new_data_type')
# ```
# </div>

# %% [markdown]
# Pada sintaks di atas, `'new_data_type'` adalah tipe data baru, seperti:
#
# * `int64`
# * `float64`
# * `category`
# * `datetime64[ns]`

# %%
# mengganti tipe data kolom maintenance_vendor
equipment['MAINTENANCE_VENDOR'] = equipment['MAINTENANCE_VENDOR'].astype('category')

# %%
# mengganti tipe data kolom lainnya
equipment['MANUFACTURER'] = equipment['MANUFACTURER'].astype('category')
equipment['DATE'] = pd.to_datetime(equipment['DATE'])

# %%
# recheck
equipment.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 307751 entries, 0 to 307750
# Data columns (total 9 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   ID                  307751 non-null  int64
#  1   DATE                307751 non-null  datetime64[ns]
#  2   MAINTENANCE_VENDOR  307751 non-null  category
#  3   MANUFACTURER        307751 non-null  category
#  4   S15                 307751 non-null  float64
#  5   S17                 307751 non-null  float64
#  6   S16                 307751 non-null  float64
#  7   AGE_OF_EQUIPMENT    307751 non-null  int64
#  8   FAILURE_TARGET      307751 non-null  int64
# dtypes: category(2), datetime64[ns](1), float64(3), int64(3)
# memory usage: 17.0 MB

# %% [markdown]
# #### Advantages of Categories
#
# Terdapat 2 keuntungan ketika kita mengubah tipe data menjadi `category`:
#
# **1️⃣ Pertama: Memory Efficient <br>**
#
# Pengubahan data object menjadi category akan menghemat memori dan menambah kecepatan komputasional. Kita dapat membandingkan dua Data Frame **sebelum dan sesudah** kolom dikonversi ke tipe data `category`:

# %%
# code here
equipment.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 307751 entries, 0 to 307750
# Data columns (total 9 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   ID                  307751 non-null  int64
#  1   DATE                307751 non-null  datetime64[ns]
#  2   MAINTENANCE_VENDOR  307751 non-null  category
#  3   MANUFACTURER        307751 non-null  category
#  4   S15                 307751 non-null  float64
#  5   S17                 307751 non-null  float64
#  6   S16                 307751 non-null  float64
#  7   AGE_OF_EQUIPMENT    307751 non-null  int64
#  8   FAILURE_TARGET      307751 non-null  int64
# dtypes: category(2), datetime64[ns](1), float64(3), int64(3)
# memory usage: 17.0 MB

# %% [markdown]
# **2️⃣ Kedua: Accessor Category `.cat`**
#
# Setiap tipe data pada sebuah Series memiliki memiliki fungsi-fungsi khusus yang dapat diaplikasikan. Untuk tipe data kategori, fungsi-fungsi tersebut dapat diakses melalui accessor `.cat`. Berikut contoh penggunaannya pada data sebuah data dummy:

# %% [markdown]
# **`rename_categories`**

# %%
# nama kota
df_cat = pd.DataFrame({"kota":['JKT', 'BDG', 'JKT', 'SBY', 'BDG', 'JKT', 'SBY', 'SBY']})
df_cat['kota'] = df_cat['kota'].astype("category")
df_cat['kota']
# Out:
# 0    JKT
# 1    BDG
# 2    JKT
# 3    SBY
# 4    BDG
# 5    JKT
# 6    SBY
# 7    SBY
# Name: kota, dtype: category
# Categories (3, object): ['BDG', 'JKT', 'SBY']

# %%
# code here
df_cat['kota'].cat.rename_categories(['Bandung','Jakarta','Surabaya'])
# Out:
# 0     Jakarta
# 1     Bandung
# 2     Jakarta
# 3    Surabaya
# 4     Bandung
# 5     Jakarta
# 6    Surabaya
# 7    Surabaya
# Name: kota, dtype: category
# Categories (3, object): ['Bandung', 'Jakarta', 'Surabaya']

# %% [markdown]
# **`reorder_categories`**

# %%
# code here
df_cat = pd.DataFrame({"size":['XXS', 'S', 'XS', 'M', 'XL', 'XXL', 'L', 'M']})
df_cat['size'] = df_cat['size'].astype("category")
df_cat['size']
# Out:
# 0    XXS
# 1      S
# 2     XS
# 3      M
# 4     XL
# 5    XXL
# 6      L
# 7      M
# Name: size, dtype: category
# Categories (7, object): ['L', 'M', 'S', 'XL', 'XS', 'XXL', 'XXS']

# %%
# code here
df_cat['size'].cat.reorder_categories(['XXS', 'XS', 'S', 'M', 'L', 'XL', 'XXL'], ordered=True)
# Out:
# 0    XXS
# 1      S
# 2     XS
# 3      M
# 4     XL
# 5    XXL
# 6      L
# 7      M
# Name: size, dtype: category
# Categories (7, object): ['XXS' < 'XS' < 'S' < 'M' < 'L' < 'XL' < 'XXL']

# %%
df_cat['size']
# Out:
# 0    XXS
# 1      S
# 2     XS
# 3      M
# 4     XL
# 5    XXL
# 6      L
# 7      M
# Name: size, dtype: category
# Categories (7, object): ['L', 'M', 'S', 'XL', 'XS', 'XXL', 'XXS']

# %% [markdown]
# ## Datetime Type

# %% [markdown]
# ### Cast Datetime Type

# %% [markdown]
# <div class="alert-warning alert" style="margin: 0 auto; color: black;">
#
# Tipe data `datetime64[ns]` digunakan untuk data waktu, seperti kolom `CustomerDOB` dan `TransactionDate` pada data `transaction`. Awalnya, data waktu sering dikenali sebagai `object` sehingga perlu **diubah** ke tipe data `datetime`.
# </div>

# %% [markdown]
# Berikut adalah beberapa cara untuk mengubah tipe data menjadi `datetime64[ns]`.

# %% [markdown]
# **1️⃣ Dengan fungsi `.astype('datetime64[ns]')`**

# %% [markdown]
# Misalkan kita memiliki data tanggal yang ditulis dengan format `DD-MM-YYYY`, format penanggalan umum yang digunakan di Indonesia.

# %%
# 30 Januari 2025 - 2 Februari
date = pd.Series(['30-01-2025', '31-01-2025', '01-02-2025','02-02-2025'])

# mengubah tipe data ke datetime dengan .astype()
date.astype('datetime64[ns]')
# Out:
# C:\Users\Hanif\AppData\Local\Temp\ipykernel_3736\3537866138.py:5: UserWarning: Parsing dates in %d-%m-%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   date.astype('datetime64[ns]')
# 0   2025-01-30
# 1   2025-01-31
# 2   2025-02-01
# 3   2025-02-02
# dtype: datetime64[ns]

# %% [markdown]
# > ℹ️ Format penanggalan `pandas` mengikuti format ISO `YYYY-MM-DD`.

# %% [markdown]
# <span style="background-color:#FFCCCC; padding: 5px; border-radius: 5px; display: block;">
#
# **⚠️ Problem with `.astype('datetime64[ns]')`**
#
# **`.astype('datetime64[ns]')` tidak kompatibel untuk semua format penulisan tanggal**. Pada contoh sebelumnya, 1 Februari 2024 dikenali sebagai 2 Januari 2024 (yang ditulis pertama dikenali sebagai bulan).
#
# </span>

# %% [markdown]
# **2️⃣ Dengan fungsi `pd.to_datetime()`**

# %% [markdown]
# `pd.to_datetime()` memberikan lebih banyak fleksibilitas untuk menyesuaikan tipe data menjadi `datetime`.

# %% [markdown]
# > 📌 [Dokumentasi `pd.to_datetime()`](https://pandas.pydata.org/docs/reference/api/pandas.to_datetime.html).

# %% [markdown]
# * Gunakan parameter `dayfirst = True` untuk memberi tahu bahwa pada penulisan tanggal, hari ditulis lebih dahulu.

# %%
# mengubah tipe data ke datetime dengan pd.to_datetime(), dayfirst = True
pd.to_datetime(date, dayfirst=True)
# Out:
# 0   2025-01-30
# 1   2025-01-31
# 2   2025-02-01
# 3   2025-02-02
# dtype: datetime64[ns]

# %% [markdown]
# * Gunakan parameter `format` untuk mendefinisikan format tanggal yang tidak baku.

# %% [markdown]
# > 📌 **Referensi** : https://strftime.org/.

# %%
# 30 Januari 2024 - 2 Februari
date2 = pd.Series(['30012025','31012025','01022025','02022025'])

# mengubah tipe data ke datetime dengan pd.to_datetime() dengan format strftime
pd.to_datetime(date2, format='%d%m%Y')
# Out:
# 0   2025-01-30
# 1   2025-01-31
# 2   2025-02-01
# 3   2025-02-02
# dtype: datetime64[ns]

# %% [markdown]
# 🎁**Additional:**

# %%
date3 = pd.Series(['2023-06-15 09:23:14','Jun 15, 2023','2023-06-16', \
     '2025-September-22', '22/Sep/2025', '2025/09/23', '23-09-2025'])

# %% [markdown]
# ❓Bagaimana mengubah tipe data datetime yang memiliki format tidak konsisten seperti di atas?

# %%
#code here
pd.to_datetime(date3,format='mixed')
# Out:
# 0   2023-06-15 09:23:14
# 1   2023-06-15 00:00:00
# 2   2023-06-16 00:00:00
# 3   2025-09-22 00:00:00
# 4   2025-09-22 00:00:00
# 5   2025-09-23 00:00:00
# 6   2025-09-23 00:00:00
# dtype: datetime64[ns]

# %% [markdown]
# <span style="background-color:#DFF2BF; padding: 10px; border-radius: 5px; display: block;">
#
# **💡 Kapan menggunakan `.astype('datetime64[ns]')` atau `pd.to_datetime()`?**
#
# - `.astype('datetime64[ns]')`: untuk data dengan format penanggalan **bulan-tanggal-tahun**.
# - `pd.to_datetime()`: bisa digunakan hampir di semua format penanggalan.
#
# </span>

# %% [markdown]
# ❓ Metode mana yang cocok untuk mengubah tipe data kolom `DATE`?

# %%
# mengubah tipe data kolom DATE pada dataframe equipment
equipment['DATE'] = pd.to_datetime(equipment['DATE'])

# recheck
equipment.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 307751 entries, 0 to 307750
# Data columns (total 9 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   ID                  307751 non-null  int64
#  1   DATE                307751 non-null  datetime64[ns]
#  2   MAINTENANCE_VENDOR  307751 non-null  category
#  3   MANUFACTURER        307751 non-null  category
#  4   S15                 307751 non-null  float64
#  5   S17                 307751 non-null  float64
#  6   S16                 307751 non-null  float64
#  7   AGE_OF_EQUIPMENT    307751 non-null  int64
#  8   FAILURE_TARGET      307751 non-null  int64
# dtypes: category(2), datetime64[ns](1), float64(3), int64(3)
# memory usage: 17.0 MB

# %% [markdown]
# ### Datetime Component Extraction

# %% [markdown]
# Setelah mengonversi tipe data menjadi `datetime`, pandas memungkinkan kita untuk mengekstrak informasi spesifik seperti tahun, bulan, hari, dan jam. Ekstraksi ini membantu dalam analisis lebih mendalam, seperti:
#
# - Hari apa yang paling sering digunakan customer untuk melakukan transaksi?
# - Bulan apa transaksi paling sering dilakukan?

# %% [markdown]
# Berikut beberapa atribut dan fungsi dapat digunakan dengan accessor `.dt` untuk mengekstrak komponen waktu dari tipe data `datetime`.

# %% [markdown]
# **Date Component (Numeric)**
#
# - `.dt.year`: ekstrak tahun.
# - `.dt.month`: ekstrak bulan (dalam angka).
# - `.dt.day`: ekstrak tanggal.
# - `.dt.dayofweek`: ekstrak urutan hari dalam 1 minggu. Misalnya, Monday = 0 dan Sunday = 6.

# %%
# ekstrak hari
equipment['DATE'].dt.day_name()
# Out:
# 0           Tuesday
# 1         Wednesday
# 2          Thursday
# 3            Friday
# 4          Saturday
#             ...
# 307746       Sunday
# 307747       Monday
# 307748      Tuesday
# 307749    Wednesday
# 307750     Thursday
# Name: DATE, Length: 307751, dtype: object

# %% [markdown]
# **Date Component (String)**
#
# - `.dt.month_name()`: ekstrak nama bulan.
# - `.dt.day_name()`: ekstak nama hari.

# %%
# ekstrak nama hari
equipment['DATE'].dt.month_name()
# Out:
# 0         December
# 1         December
# 2         December
# 3         December
# 4         December
#             ...
# 307746    November
# 307747    November
# 307748    November
# 307749    November
# 307750    December
# Name: DATE, Length: 307751, dtype: object

# %% [markdown]
# Untuk menyimpan komponen waktu yang sudah diekstrak ke dataframe:

# %%
# menyimpan nama hari ke kolom baru
equipment['DAY_OBS'] = equipment['DATE'].dt.day_name()
equipment.head()
# Out:
#        ID       DATE  MAINTENANCE_VENDOR         MANUFACTURER   S15    S17
# 0  100001 2014-12-02  Optimech Solutions  Yokentra Industries 11.09 145.22  \
# 1  100001 2014-12-03  Optimech Solutions  Yokentra Industries  8.88 187.57
# 2  100001 2014-12-04  Optimech Solutions  Yokentra Industries  8.68 148.36
# 3  100001 2014-12-05  Optimech Solutions  Yokentra Industries  9.99 133.66
# 4  100001 2014-12-06  Optimech Solutions  Yokentra Industries  8.48 197.18
#
#    S16  AGE_OF_EQUIPMENT  FAILURE_TARGET    DAY_OBS
# 0 8.43               880               0    Tuesday
# 1 6.48               881               0  Wednesday
# 2 6.16               882               0   Thursday
# 3 9.32               883               0     Friday
# 4 8.02               884               0   Saturday

# %% [markdown]
# ### Datetime Transformation

# %% [markdown]
# Selain mengekstrak komponen waktu secara individual dari kolom `datetime`, kita juga bisa mengekstrak komponen periode, yang memudahkan analisis dalam kerangka waktu yang lebih luas. Misalnya:
#
# * Di minggu ke berapa pinjaman banyak diberikan?
# * Pada kuartal mana pengajuan pinjaman paling tinggi?
#
# Berikut adalah beberapa fungsi datetime transformation yang dapat diakses melalui accessor `dt`
#
# - `.dt.to_period('D')`: mengubah ke format tanggal lengkap.
# - `.dt.to_period('W')`: mengubah ke format awal minggu/akhir minggu.
# - `.dt.to_period('M')`: mengubah ke format year-month.
# - `.dt.to_period('Q')`: mengubah ke format year-quartal.

# %%
# ekstrak komponen quartal
equipment['DATE'].dt.to_period('D')
# Out:
# 0         2014-12-02
# 1         2014-12-03
# 2         2014-12-04
# 3         2014-12-05
# 4         2014-12-06
#              ...
# 307746    2016-11-27
# 307747    2016-11-28
# 307748    2016-11-29
# 307749    2016-11-30
# 307750    2016-12-01
# Name: DATE, Length: 307751, dtype: period[D]

# %%
# menyimpan komponen quartal ke kolom baru
equipment['QUARTAL_OBS'] = equipment['DATE'].dt.to_period('Q')

# %% [markdown]
# # 4. Indexing & Subsetting

# %% [markdown]
# ## Slicing `[]` Operator

# %% [markdown]
# Slicing operator digunakan untuk subsetting baris berdasarkan indeksnya.

# %% [markdown]
#
# ```python
# # sintaks subsetting dengan slicing operator ([])
# dataframe_name[start:end]
# ```

# %% [markdown]
# **📌 Catatan**
#
# * `start` bersifat **inklusif** (dimasukkan dalam pengambilan data).
# * `end` bersifat **ekslusif** (tidak dimasukkan dalam pengambilan data).
# * Baris pertama memiliki indeks 0 (zero based indexing), dst.

# %%
# contoh subsetting dengan slicing operator
equipment[0:3]
# Out:
#        ID       DATE  MAINTENANCE_VENDOR         MANUFACTURER   S15    S17
# 0  100001 2014-12-02  Optimech Solutions  Yokentra Industries 11.09 145.22  \
# 1  100001 2014-12-03  Optimech Solutions  Yokentra Industries  8.88 187.57
# 2  100001 2014-12-04  Optimech Solutions  Yokentra Industries  8.68 148.36
#
#    S16  AGE_OF_EQUIPMENT  FAILURE_TARGET    DAY_OBS QUARTAL_OBS
# 0 8.43               880               0    Tuesday      2014Q4
# 1 6.48               881               0  Wednesday      2014Q4
# 2 6.16               882               0   Thursday      2014Q4

# %% [markdown]
# Pada contoh di atas, data yang diambil adalah data dengan indeks baris 0-2 (baris ke-1 hingga ke-3). Baris dengan indeks baris 3 tidak dimasukkan.

# %% [markdown]
# **▶️ Study Case:** Tampilkan baris ke-100 sampai baris ke-105.

# %%
# code here
equipment[99:106]
# Out:
#          ID       DATE  MAINTENANCE_VENDOR         MANUFACTURER  S15  S17
# 99   100001 2015-03-11  Optimech Solutions  Yokentra Industries 0.00 0.00  \
# 100  100001 2015-03-12  Optimech Solutions  Yokentra Industries 0.00 0.00
# 101  100001 2015-03-13  Optimech Solutions  Yokentra Industries 0.00 0.00
# 102  100001 2015-03-14  Optimech Solutions  Yokentra Industries 0.00 0.00
# 103  100001 2015-03-15  Optimech Solutions  Yokentra Industries 0.00 0.00
# 104  100001 2015-03-16  Optimech Solutions  Yokentra Industries 0.00 0.00
# 105  100001 2015-03-17  Optimech Solutions  Yokentra Industries 0.00 0.00
#
#       S16  AGE_OF_EQUIPMENT  FAILURE_TARGET    DAY_OBS QUARTAL_OBS
# 99  10.03               979               0  Wednesday      2015Q1
# 100  9.08               980               0   Thursday      2015Q1
# 101  8.89               981               0     Friday      2015Q1
# 102  8.99               982               0   Saturday      2015Q1
# ...

# %% [markdown]
# **▶️ Study Case:** Tampilkan baris ke-342 sampai baris ke-378.

# %%
# code here
equipment[341:379]
# Out:
#          ID       DATE  MAINTENANCE_VENDOR         MANUFACTURER   S15  S17
# 341  100001 2015-11-08  Optimech Solutions  Yokentra Industries 26.40 0.00  \
# 342  100001 2015-11-09  Optimech Solutions  Yokentra Industries 22.32 0.00
# 343  100001 2015-11-10  Optimech Solutions  Yokentra Industries 19.92 0.00
# 344  100001 2015-11-11  Optimech Solutions  Yokentra Industries 29.76 0.00
# 345  100001 2015-11-12  Optimech Solutions  Yokentra Industries 27.84 0.00
# 346  100001 2015-11-13  Optimech Solutions  Yokentra Industries 18.96 0.00
# 347  100001 2015-11-14  Optimech Solutions  Yokentra Industries 21.12 0.00
# 348  100001 2015-11-15  Optimech Solutions  Yokentra Industries 25.19 0.00
# 349  100001 2015-11-16  Optimech Solutions  Yokentra Industries 23.04 0.00
# 350  100001 2015-11-17  Optimech Solutions  Yokentra Industries 29.04 0.00
# 351  100001 2015-11-18  Optimech Solutions  Yokentra Industries 28.56 0.00
# ...

# %% [markdown]
# **▶️ Study Case:** Tampilkan baris ke-25 sampai baris ke-55.

# %%
# code here
equipment[24:56]
# Out:
#         ID       DATE  MAINTENANCE_VENDOR         MANUFACTURER   S15  S17
# 24  100001 2014-12-26  Optimech Solutions  Yokentra Industries 28.56 0.00  \
# 25  100001 2014-12-27  Optimech Solutions  Yokentra Industries 20.40 0.00
# 26  100001 2014-12-28  Optimech Solutions  Yokentra Industries 29.28 0.00
# 27  100001 2014-12-29  Optimech Solutions  Yokentra Industries 24.24 0.00
# 28  100001 2014-12-30  Optimech Solutions  Yokentra Industries 29.76 0.00
# 29  100001 2014-12-31  Optimech Solutions  Yokentra Industries 21.84 0.00
# 30  100001 2015-01-01  Optimech Solutions  Yokentra Industries 21.60 0.00
# 31  100001 2015-01-02  Optimech Solutions  Yokentra Industries 30.00 0.00
# 32  100001 2015-01-03  Optimech Solutions  Yokentra Industries 25.20 0.00
# 33  100001 2015-01-04  Optimech Solutions  Yokentra Industries 27.36 0.00
# 34  100001 2015-01-05  Optimech Solutions  Yokentra Industries 27.84 0.00
# 35  100001 2015-01-06  Optimech Solutions  Yokentra Industries 26.40 0.00
# ...

# %% [markdown]
# ## `.iloc[rows, columns]`

# %% [markdown]
# `.iloc[rows, columns]` digunakan untuk subsetting baris dan kolom berdasarkan indeksnya.

# %% [markdown]
#  <div style="background-color:#90EE90; padding: 5px; border-radius: 5px; border: 2px solid #000000;">
#
# ```python
# # sintaks subsetting dengan .iloc[]
# dataframe_name.iloc[start:end, start:end]
# ```

# %% [markdown]
# **📌 Catatan**
#
# * `start` pada baris dan kolom sama-sama bersifat inklusif.
# * `end` pada baris dan kolom sama-sama bersifat ekslusif.
# * Jika ingin memasukkan semua baris/kolom, `start:end` dapat diganti menjadi `:`.

# %%
# contoh subsetting dengan .iloc[]
equipment.iloc[0:5,0:3]
# Out:
#        ID       DATE  MAINTENANCE_VENDOR
# 0  100001 2014-12-02  Optimech Solutions
# 1  100001 2014-12-03  Optimech Solutions
# 2  100001 2014-12-04  Optimech Solutions
# 3  100001 2014-12-05  Optimech Solutions
# 4  100001 2014-12-06  Optimech Solutions

# %% [markdown]
# Pada contoh di atas, kita:
#
# * Mengambil data dengan indeks baris 0-4 (baris ke-1 sampai ke-5).
# * Mengambil data dengan indeks baris 0-2 (kolom ke-1 sampai ke-3).

# %% [markdown]
# **▶️ Study Case:** Tampilkan 5 baris pertama beserta kolom `ID` sampai `MANUFACTURER`.

# %%
# code here
equipment.iloc[0:4,0:4]
# Out:
#        ID       DATE  MAINTENANCE_VENDOR         MANUFACTURER
# 0  100001 2014-12-02  Optimech Solutions  Yokentra Industries
# 1  100001 2014-12-03  Optimech Solutions  Yokentra Industries
# 2  100001 2014-12-04  Optimech Solutions  Yokentra Industries
# 3  100001 2014-12-05  Optimech Solutions  Yokentra Industries

# %% [markdown]
# **▶️ Study Case:** Tampilkan baris dengan indeks 1, 3, dan 5. Diikuti dengan kolom `ID`, `MANUFACTURER`, `AGE_OF_EQUIPMENT` dan `FAILURE_TARGET`

# %%
# code here
equipment.iloc[[1,3,5],[0,3,7,8]]
# Out:
#        ID         MANUFACTURER  AGE_OF_EQUIPMENT  FAILURE_TARGET
# 1  100001  Yokentra Industries               881               0
# 3  100001  Yokentra Industries               883               0
# 5  100001  Yokentra Industries               885               0

# %% [markdown]
# ## `.loc[rows, columns]`

# %% [markdown]
# `loc[rows, columns]` digunakan untuk subsetting baris dan kolom berdasarkan namanya.

# %% [markdown]
#  <div style="background-color:#90EE90; padding: 5px; border-radius: 5px; border: 2px solid #000000;">
#
# ```python
# # sintaks subsetting dengan .loc[]
# dataframe_name.loc[rows, columns]
# ```

# %%
# contoh subsetting dengan .loc[]
equipment.loc[0:5,['ID','MANUFACTURER','AGE_OF_EQUIPMENT']]
# Out:
#        ID         MANUFACTURER  AGE_OF_EQUIPMENT
# 0  100001  Yokentra Industries               880
# 1  100001  Yokentra Industries               881
# 2  100001  Yokentra Industries               882
# 3  100001  Yokentra Industries               883
# 4  100001  Yokentra Industries               884
# 5  100001  Yokentra Industries               885

# %% [markdown]
# Pada contoh di atas, kita:
#
# * Mengambil baris dengan indeks 0-5.
# * Mengambil kolom `ID`,`MANUFACTURER` dan `AGE_OF_EQUIPMENT`

# %% [markdown]
# **▶️ Study Case:** Perusahaan ingin melakukan pengamatan pada mesin dengan `ID` 100001, 100002 dan 100003. Ambil informasi `MAINTENANCE_VENDOR` untuk mengetahui vendor mana yang bertanggung jawab pada ke-3 jenis mesin tersebut

# %%
# set id sebagai index
equipment_id = equipment.set_index('ID')
equipment_id.head()
# Out:
#              DATE  MAINTENANCE_VENDOR         MANUFACTURER   S15    S17  S16
# ID
# 100001 2014-12-02  Optimech Solutions  Yokentra Industries 11.09 145.22 8.43  \
# 100001 2014-12-03  Optimech Solutions  Yokentra Industries  8.88 187.57 6.48
# 100001 2014-12-04  Optimech Solutions  Yokentra Industries  8.68 148.36 6.16
# 100001 2014-12-05  Optimech Solutions  Yokentra Industries  9.99 133.66 9.32
# 100001 2014-12-06  Optimech Solutions  Yokentra Industries  8.48 197.18 8.02
#
#         AGE_OF_EQUIPMENT  FAILURE_TARGET    DAY_OBS QUARTAL_OBS
# ID
# 100001               880               0    Tuesday      2014Q4
# 100001               881               0  Wednesday      2014Q4
# 100001               882               0   Thursday      2014Q4
# 100001               883               0     Friday      2014Q4
# 100001               884               0   Saturday      2014Q4

# %%
# code here
equipment_id.loc[100001:100005,['MANUFACTURER','MAINTENANCE_VENDOR']].drop_duplicates()
# Out:
#                  MANUFACTURER         MAINTENANCE_VENDOR
# ID
# 100001    Yokentra Industries         Optimech Solutions
# 100002  Rivatek Manufacturing  Liftek Machinery Services
# 100003     Trimech Industries  Liftek Machinery Services

# %% [markdown]
# ## Conditional Subsetting

# %% [markdown]
# Selain subsetting berdasarkan posisi baris dan kolom, kita juga bisa melakukan subsetting berdasarkan kondisi tertentu (conditional subsetting). Berikut adalah sintaks conditional subsetting.

# %% [markdown]
#  <div style="background-color:#90EE90; padding: 5px; border-radius: 5px; border: 2px solid #000000;">
#
# ```python
# # sintaks conditional subsetting
# dataframe_name[dataframe_name['column_name'] <comparison_operator> <value>]
# ```

# %% [markdown]
# **📌 Operator Perbandingan**
#
# - `<` - lebih kecil dari (yaitu : a < b).
# - `<=` - lebih kecil atau sama dengan (yaitu : a <= b).
# - `>` - lebih besar dari (yaitu: a > b).
# - `>=` - lebih besar atau sama dengan (yaitu: a >= b).
# - `==` - sama dengan (yaitu: a == b).
# - `!=` - tidak Sama dengan (yaitu: a != b).

# %%
# contoh conditional subsetting
# data equipment dengan target failure 0
equipment[equipment['FAILURE_TARGET'] == 0]
# Out:
#             ID       DATE      MAINTENANCE_VENDOR         MANUFACTURER   S15
# 0       100001 2014-12-02      Optimech Solutions  Yokentra Industries 11.09  \
# 1       100001 2014-12-03      Optimech Solutions  Yokentra Industries  8.88
# 2       100001 2014-12-04      Optimech Solutions  Yokentra Industries  8.68
# 3       100001 2014-12-05      Optimech Solutions  Yokentra Industries  9.99
# 4       100001 2014-12-06      Optimech Solutions  Yokentra Industries  8.48
# ...        ...        ...                     ...                  ...   ...
# 307746  100617 2016-11-27  Proxima Machinery Care   Steelon Industries 29.52
# 307747  100617 2016-11-28  Proxima Machinery Care   Steelon Industries 24.24
# 307748  100617 2016-11-29  Proxima Machinery Care   Steelon Industries 28.56
# 307749  100617 2016-11-30  Proxima Machinery Care   Steelon Industries 23.28
# 307750  100617 2016-12-01  Proxima Machinery Care   Steelon Industries 21.84
#
# ...

# %% [markdown]
# **▶️ Study Case:** Perusahaan ingin menganalisis mesin yang di produksi oleh `Quantum Forge`. Tampilkan data tersebut!

# %%
#code here
equipment[equipment['MANUFACTURER'] == 'Quantum Forge']
# Out:
#             ID       DATE       MAINTENANCE_VENDOR   MANUFACTURER   S15  S17
# 8041    100019 2014-12-02  Mechatronix Maintenance  Quantum Forge  0.00 0.00  \
# 8042    100019 2014-12-03  Mechatronix Maintenance  Quantum Forge  0.00 0.00
# 8043    100019 2014-12-04  Mechatronix Maintenance  Quantum Forge  0.00 0.00
# 8044    100019 2014-12-05  Mechatronix Maintenance  Quantum Forge  0.00 0.00
# 8045    100019 2014-12-06  Mechatronix Maintenance  Quantum Forge  0.00 0.00
# ...        ...        ...                      ...            ...   ...  ...
# 296050  100595 2016-11-27      Kinetra Engineering  Quantum Forge 18.96 0.00
# 296051  100595 2016-11-28      Kinetra Engineering  Quantum Forge 20.88 0.00
# 296052  100595 2016-11-29      Kinetra Engineering  Quantum Forge 25.20 0.00
# 296053  100595 2016-11-30      Kinetra Engineering  Quantum Forge 20.40 0.00
# 296054  100595 2016-12-01      Kinetra Engineering  Quantum Forge 18.00 0.00
#
# ...

# %% [markdown]
# #### Multiple Conditions

# %% [markdown]
# Jika terdapat banyak kondisi untuk conditional subsetting, kita bisa menggunakan operator `&` (AND) dan (`|`) (OR).

# %% [markdown]
# <span style="background-color:#f0f0f0; padding: 10px; border-radius: 5px; display: block;">
#
# **AND Operator (`&`)**
#
#   - Semua syarat harus terpenuhi.
#   - Digunakan untuk kondisi dari kolom yang berbeda.
#
# **OR Operator (`|`)**
#
#   - Hanya perlu salah satu kondisi yang terpenuhi.
#   - Digunakan untuk kondisi dari kolom yang sama.
#
# </span>

# %% [markdown]
# Misalkan, kita ingin mengambil informasi dengan kriteria:
# * Tanggal pengamatan (`DATE`) adalah `30 November 2015`
# * Kondisi mesin `Rusak` (`FAILURE_TARGET` = 1)

# %%
# cara 1
cond1 = equipment['DATE'] == '30 November 2015'
cond2 = equipment['FAILURE_TARGET'] == 0

# %%
# cara 2
equipment[cond1 & cond2]
# Out:
#             ID       DATE         MAINTENANCE_VENDOR           MANUFACTURER
# 363     100001 2015-11-30         Optimech Solutions    Yokentra Industries  \
# 1094    100002 2015-11-30  Liftek Machinery Services  Rivatek Manufacturing
# 1825    100003 2015-11-30  Liftek Machinery Services     Trimech Industries
# 2556    100006 2015-11-30       Jetronix Maintenance     Steelon Industries
# 3287    100007 2015-11-30          Novamech Services      Wahana Teknikindo
# ...        ...        ...                        ...                    ...
# 304459  100612 2015-11-30         Optimech Solutions      Vortek Industries
# 305190  100613 2015-11-30         Optimech Solutions    Yokentra Industries
# 305921  100614 2015-11-30        Kinetra Engineering     Trimech Industries
# 306652  100616 2015-11-30         Optimech Solutions     Steelon Industries
# 307383  100617 2015-11-30     Proxima Machinery Care     Steelon Industries
#
# ...

# %% [markdown]
# **▶️ Study Case:** Tampilkan data yang memenuhi kriteria ini!
#
# * Mesin yang di produksi oleh `Zentron Manufacturing` atau `Ultimech Industries`.
# * Dimaintain oleh `Proxima Machinery Care`
# * Memiliki usia > 3 tahun.

# %%
#code here

cond1 = equipment['MANUFACTURER'].isin(['Zentron Manufacturing','Ultimech Industries'])
cond2 = equipment['MAINTENANCE_VENDOR'] == 'Proxima Machinery Care'
cond3 = equipment['AGE_OF_EQUIPMENT'] > 3*365
equipment[cond1 & cond2 & cond3]
# Out:
#             ID       DATE      MAINTENANCE_VENDOR           MANUFACTURER
# 24123   100049 2014-12-02  Proxima Machinery Care  Zentron Manufacturing  \
# 24124   100049 2014-12-03  Proxima Machinery Care  Zentron Manufacturing
# 24125   100049 2014-12-04  Proxima Machinery Care  Zentron Manufacturing
# 24126   100049 2014-12-05  Proxima Machinery Care  Zentron Manufacturing
# 24127   100049 2014-12-06  Proxima Machinery Care  Zentron Manufacturing
# ...        ...        ...                     ...                    ...
# 303360  100610 2016-11-27  Proxima Machinery Care  Zentron Manufacturing
# 303361  100610 2016-11-28  Proxima Machinery Care  Zentron Manufacturing
# 303362  100610 2016-11-29  Proxima Machinery Care  Zentron Manufacturing
# 303363  100610 2016-11-30  Proxima Machinery Care  Zentron Manufacturing
# 303364  100610 2016-12-01  Proxima Machinery Care  Zentron Manufacturing
#
#          S15  S17  S16  AGE_OF_EQUIPMENT  FAILURE_TARGET    DAY_OBS
# ...

# %% [markdown]
# # 5. Exploratory Data Analysis with `pd.crosstab()`

# %% [markdown]
# <div class="alert-warning alert" style="margin: 0 auto; color: black;">
#
# Salah satu langkah sederhana dalam exploratory data analysis (EDA) adalah membuat **cross tabulation**. Teknik ini membantu memahami hubungan antara dua atau lebih variabel dalam dataset, baik dengan melihat frekuensi kemunculan data (**tabel frekuensi**) maupun pola numerik lainnya (**tabel agregasi**) berdasarkan gabungan dari variabel-variabel tersebut.
# </div>

# %% [markdown]
# Perhatikan parameter pada fungsi `pd.crosstab()` berikut.
#
# <div style="background-color:#90EE90; padding: 5px; border-radius: 5px; border: 2px solid #000000;">
#
# ```python
# pd.crosstab(
#     index,
#     columns,
#     values,
#     aggfunc,
#     normalize,
#     margins
# )
# ```
#
# </div>

# %% [markdown]
# * `index`: variabel yang berperan sebagai label baris.
# * `columns`: variabel yang berperan sebagai label kolom.
# * `values`: variabel yang akan digunakan untuk agregasi antara baris dan kolom.
# * `aggfunc`: fungsi agregasi yang diterapkan pada data yang dipilih oleh `values`.
#    - `'min'`: nilai minimum.
#    - `'max'`: nilai maksimum.
#    - `'count'`: frekuensi.
#    - `'sum'`: nilai total.
#    - `'mean'`: nilai rata-rata.
#    - `'median'`: nilai tengah
# * `normalize`: menormalkan hasil crosstab menjadi proporsi total atau sepanjang baris/kolom.
#    - `normalize = 'all'`: menghitung proporsi terhadap keseluruhan.
#    - `normalize = 'index'`: menghitung proporsi terhadap baris.
#    - `normalize = 'columns'`: menghitung proporsi terhadap kolom.
# * `margins`
#    - `margins = True`: menambahkan total baris dan kolom ke tabel.

# %% [markdown]
# ### 🧐 Case 1: Menghitung banyak mesin yang rusak dan tidak rusak

# %%
#code here
pd.crosstab(
    index=equipment['FAILURE_TARGET'],
    columns='jumlah'
)
# Out:
# col_0           jumlah
# FAILURE_TARGET
# 0               296011
# 1                11740

# %%
equipment['FAILURE_TARGET'].value_counts()
# Out:
# FAILURE_TARGET
# 0    296011
# 1     11740
# Name: count, dtype: int64

# %% [markdown]
# > ℹ️ Parameter `index` dan `columns` adalah parameter wajib. Jika crosstab hanya dilakukan pada satu kolom, kedua parameter ini dapat diisi dengan string.
#
# > ℹ️ Default penggunaan `pd.crosstab()` adalah untuk menghitung frekuensi.

# %% [markdown]
# ### 🧐 Case 2: Menghitung banyak mesin rusak/tidak rusak beserta maintenance vendor yang bertanggung jawab

# %%
#code here
equipment[equipment['DATE'].dt.year.between(2014,2016)].groupby(equipment['MAINTENANCE_VENDOR'])['FAILURE_TARGET'].value_counts()
# Out:
# MAINTENANCE_VENDOR         FAILURE_TARGET
# Industrium Services        0                 32338
#                            1                  1288
# Jetronix Maintenance       0                 40774
#                            1                  1624
# Kinetra Engineering        0                 37280
#                            1                  1463
# Liftek Machinery Services  0                 32338
#                            1                  1288
# Mechatronix Maintenance    0                 40088
#                            1                  1579
# Novamech Services          0                 35853
#                            1                  1428
# Optimech Solutions         0                 40081
#                            1                  1586
# Proxima Machinery Care     0                 37259
#                            1                  1484
# Name: count, dtype: int64

# %% [markdown]
# Tambahkan parameter `margins` untuk menambahkan subtotal.

# %%
#code here
pd.crosstab(
    index=equipment['MAINTENANCE_VENDOR'],
    columns=equipment['FAILURE_TARGET'],
    margins=True
)
# Out:
# FAILURE_TARGET                  0      1     All
# MAINTENANCE_VENDOR
# Industrium Services         32338   1288   33626
# Jetronix Maintenance        40774   1624   42398
# Kinetra Engineering         37280   1463   38743
# Liftek Machinery Services   32338   1288   33626
# Mechatronix Maintenance     40088   1579   41667
# Novamech Services           35853   1428   37281
# Optimech Solutions          40081   1586   41667
# Proxima Machinery Care      37259   1484   38743
# All                        296011  11740  307751

# %% [markdown]
# Tambahkan parameter `normalize` untuk membuat proporsi.

# %%
#code here
#code here
pd.crosstab(
    index=equipment['MAINTENANCE_VENDOR'],
    columns=equipment['FAILURE_TARGET'],
    normalize=True
)
# Out:
# FAILURE_TARGET               0    1
# MAINTENANCE_VENDOR
# Industrium Services       0.11 0.00
# Jetronix Maintenance      0.13 0.01
# Kinetra Engineering       0.12 0.00
# Liftek Machinery Services 0.11 0.00
# Mechatronix Maintenance   0.13 0.01
# Novamech Services         0.12 0.00
# Optimech Solutions        0.13 0.01
# Proxima Machinery Care    0.12 0.00

# %% [markdown]
# ### 🧐 Case 3: Menghitung rata-rata nilai sensor `S15` pada pengukuran di setiap hari nya

# %%
pd.crosstab(
    index=equipment['DAY_OBS'],
    values=equipment['S15'],
    aggfunc=['mean','sum'],
    columns = 'S15'
)
# Out:
#            mean       sum
# col_0       S15       S15
# DAY_OBS
# Friday    14.61 639898.99
# Monday    14.46 632928.27
# Saturday  14.56 637380.71
# Sunday    14.57 638042.07
# Thursday  14.70 649615.45
# Tuesday   14.56 643842.09
# Wednesday 14.63 646899.82

# %%
#code here
pd.DataFrame(equipment.groupby('DAY_OBS')['S15'].agg(mean='mean',sum='sum'))
# Out:
#            mean       sum
# DAY_OBS
# Friday    14.61 639898.99
# Monday    14.46 632928.27
# Saturday  14.56 637380.71
# Sunday    14.57 638042.07
# Thursday  14.70 649615.45
# Tuesday   14.56 643842.09
# Wednesday 14.63 646899.82

# %% [markdown]
# 🏄‍♀️ ***Dive Deeper (15 menit)***

# %% [markdown]
# Untuk memperkuat pemahaman kita sejauh ini, mari kita berlatih.

# %% [markdown]
# 1. Apabila dilihat dari tanggal pengamatan, hari apakah pengamatan paling banyak dilakukan?

# %%
pd.crosstab(
    index=equipment['DAY_OBS'],
    columns='count'
).sort_values(by='count',ascending=False)
# Out:
# col_0      count
# DAY_OBS
# Thursday   44205
# Tuesday    44205
# Wednesday  44205
# Friday     43784
# Monday     43784
# Saturday   43784
# Sunday     43784

# %%
#code here
#code here
pd.DataFrame(equipment['DAY_OBS'].value_counts().sort_values(ascending=False))
# Out:
#            count
# DAY_OBS
# Tuesday    44205
# Wednesday  44205
# Thursday   44205
# Friday     43784
# Saturday   43784
# Sunday     43784
# Monday     43784

# %% [markdown]
# 2. Selama tahun 2015, berapakah rata-rata usia mesin yang gagal dan tidak gagal? Kelompokkan berdasarkan perusahaan yang menciptakan mesin tersebut

# %%
pd.DataFrame(equipment[equipment['DATE'].dt.year ==2015].groupby(['MANUFACTURER','FAILURE_TARGET'])['AGE_OF_EQUIPMENT'].mean().sort_values(ascending=False)).rename(columns={'AGE_OF_EQUIPMENT':'AVG_AGE_OF_EQUIPMENT'})
# Out:
#                                       AVG_AGE_OF_EQUIPMENT
# MANUFACTURER          FAILURE_TARGET
# Zentron Manufacturing 1                            6974.45
# Steelon Industries    1                            5742.69
# Wahana Teknikindo     1                            5139.31
# Trimech Industries    1                            4752.67
#                       0                            3253.89
# Wahana Teknikindo     0                            3199.53
# Xelora Manufacturing  1                            3076.82
# Zentron Manufacturing 0                            3048.72
# Ultimech Industries   1                            2887.31
# Steelon Industries    0                            2796.44
# Yokentra Industries   1                            2768.42
# Quantum Forge         1                            2580.36
# Vortek Industries     1                            2454.53
# Yokentra Industries   0                            1954.18
# ...

# %%
pd.crosstab(
    index=equipment[equipment['DATE'].dt.year == 2015]['MANUFACTURER'],
    columns=equipment['FAILURE_TARGET'],
    values = equipment['AGE_OF_EQUIPMENT'],
    aggfunc = 'mean'
).sort_values(by=1,ascending=False)
# Out:
# FAILURE_TARGET              0       1
# MANUFACTURER
# Zentron Manufacturing 3048.72 6974.45
# Steelon Industries    2796.44 5742.69
# Wahana Teknikindo     3199.53 5139.31
# Trimech Industries    3253.89 4752.67
# Xelora Manufacturing  1803.61 3076.82
# Ultimech Industries   1775.76 2887.31
# Yokentra Industries   1954.18 2768.42
# Quantum Forge         1822.15 2580.36
# Vortek Industries     1429.89 2454.53
# Rivatek Manufacturing 1319.89 1434.82

# %% [markdown]
# # 5. Dealing with Untidy Data

# %% [markdown]
# <div class="alert-warning alert" style="margin: 0 auto; color: black;">
#
# Dalam pengolahan data, tidak semua data yang kita miliki adalah data yang bersih. Data mungkin memiliki nilai kosong (missing values) atau nilai berulang (duplicated values).
#
# Penanganan masalah ini sangat penting karena data yang tidak bersih dapat menyebabkan analisis yang salah, hasil yang tidak akurat, dan kesimpulan yang menyesatkan. Oleh karena itu, perlu diterapkan metode untuk **menangani nilai yang hilang (missing values) dan nilai duplikat (duplicated values)** guna memastikan integritas dan kualitas analisis.
#
# </div>

# %% [markdown]
# ## Missing Values

# %% [markdown]
# > **Missing values** adalah kondisi di mana value pada data tidak diketahui, tidak ada, atau tidak berlaku. Dalam konteks pemrograman dan analisis data, nilai null ini sering kali diwakili dengan nilai khusus seperti `NULL`, `None`, `NaN` (Not a Number).

# %% [markdown]
# Mari kita lihat contoh data missing berikut.

# %%
equipment_missing = pd.read_csv('data_input/equipment_missing.csv', index_col='ID', parse_dates = ['DATE'])
equipment_missing
# Out:
#              DATE         MAINTENANCE_VENDOR           MANUFACTURER   S15
# ID
# 99994         NaT                        NaN                    NaN   NaN  \
# 99995         NaT                        NaN                    NaN   NaN
# 99996         NaT                        NaN                    NaN   NaN
# 99997  2014-11-30        Kinetra Engineering          Quantum Forge 19.26
# 99998         NaT                        NaN                    NaN   NaN
# 99999         NaT                        NaN                    NaN   NaN
# 100000        NaT                        NaN                    NaN   NaN
# 100001 2014-12-02         Optimech Solutions    Yokentra Industries 11.09
# 100002 2014-12-02  Liftek Machinery Services  Rivatek Manufacturing 23.52
# 100003 2014-12-02  Liftek Machinery Services     Trimech Industries 11.13
# 100006 2014-12-02       Jetronix Maintenance     Steelon Industries 24.24
# 100007 2014-12-02          Novamech Services      Wahana Teknikindo 18.72
# ...

# %% [markdown]
# ### Step 1: Check Missing Values

# %% [markdown]
# Untuk memeriksa apakah terdapat missing values pada data, method yang umum digunakan:
#
# * `.isna()`: mengembalikan `True` apabila missing values.
# * `.notna()`: mengembalikan `True` apabila bukan missing values.

# %%
# cek missing values dengan .isna()
equipment_missing.isna()
# Out:
#          DATE  MAINTENANCE_VENDOR  MANUFACTURER    S15    S17    S16
# ID
# 99994    True                True          True   True   True   True  \
# 99995    True                True          True   True   True   True
# 99996    True                True          True   True   True   True
# 99997   False               False         False  False  False  False
# 99998    True                True          True   True   True   True
# 99999    True                True          True   True   True   True
# 100000   True                True          True   True   True   True
# 100001  False               False         False  False  False  False
# 100002  False               False         False  False  False  False
# 100003  False               False         False  False  False  False
# 100006  False               False         False  False  False  False
# 100007  False               False         False  False  False  False
# ...

# %% [markdown]
# Untuk menghitung banyaknya missing values di setiap kolom, kita dapat melanjutkan fungsi `.isna()` dengan `.sum()`.
#
# * `True` akan dihitung sebagai 1 missing values.
# * `False` akan dihitung sebagai 0 missing values.

# %%
# untuk menghitung banyaknya missing values di setiap kolom
equipment_missing.isna().sum()
# Out:
# DATE                  6
# MAINTENANCE_VENDOR    6
# MANUFACTURER          6
# S15                   6
# S17                   6
# S16                   6
# AGE_OF_EQUIPMENT      9
# dtype: int64

# %% [markdown]
# ❓ Apakah terdapat missing values pada dataframe `equipment` sebelumnya?

# %%
# cek missing values pada dataframe equipment
equipment.isna().sum()
# Out:
# ID                    0
# DATE                  0
# MAINTENANCE_VENDOR    0
# MANUFACTURER          0
# S15                   0
# S17                   0
# S16                   0
# AGE_OF_EQUIPMENT      0
# FAILURE_TARGET        0
# DAY_OBS               0
# QUARTAL_OBS           0
# dtype: int64

# %% [markdown]
# ### Step 2: Handle Missing Values

# %% [markdown]
# <span style="background-color:#DFF2BF; padding: 10px; border-radius: 5px; display: block;">
#
# **💡 Bagaimana Cara Meng-handle Missing Values?**
#
# - Menghapus missing values.
# - Mengisi missing values.
# - Tetap mempertahankan missing values.
#
# </span>

# %% [markdown]
# #### Drop Missing Values

# %% [markdown]
# > Untuk menghapus missing values, kita dapat menggunakan method `.dropna()`.
#
# `.dropna()` bekerja sesuai parameter yang kita atur:

# %% [markdown]
# - `.dropna(how = 'any')`: hapus baris apabila memiliki **minimal 1 kolom** dengan missing values.
#
# - `.dropna(how = 'all')`: hapus baris apabila memiliki **semua kolomnya** missing values.
#
# - `.dropna(subset = 'column_names')`: hapus baris apabila `"column_names"` memiliki missing values (proses drop missing values berdasarkan kolom tertentu).

# %%
equipment_missing
# Out:
#              DATE         MAINTENANCE_VENDOR           MANUFACTURER   S15
# ID
# 99994         NaT                        NaN                    NaN   NaN  \
# 99995         NaT                        NaN                    NaN   NaN
# 99996         NaT                        NaN                    NaN   NaN
# 99997  2014-11-30        Kinetra Engineering          Quantum Forge 19.26
# 99998         NaT                        NaN                    NaN   NaN
# 99999         NaT                        NaN                    NaN   NaN
# 100000        NaT                        NaN                    NaN   NaN
# 100001 2014-12-02         Optimech Solutions    Yokentra Industries 11.09
# 100002 2014-12-02  Liftek Machinery Services  Rivatek Manufacturing 23.52
# 100003 2014-12-02  Liftek Machinery Services     Trimech Industries 11.13
# 100006 2014-12-02       Jetronix Maintenance     Steelon Industries 24.24
# 100007 2014-12-02          Novamech Services      Wahana Teknikindo 18.72
# ...

# %%
# dropna(how = 'any')
# baris yang memiliki missing values akan di-drop.
equipment_missing.dropna(how='any')
# Out:
#              DATE         MAINTENANCE_VENDOR          MANUFACTURER   S15
# ID
# 99997  2014-11-30        Kinetra Engineering         Quantum Forge 19.26  \
# 100006 2014-12-02       Jetronix Maintenance    Steelon Industries 24.24
# 100007 2014-12-02          Novamech Services     Wahana Teknikindo 18.72
# 100009 2014-12-02    Mechatronix Maintenance  Xelora Manufacturing 25.64
# 100014 2014-12-02    Mechatronix Maintenance    Steelon Industries  6.29
# 100015 2014-12-02        Kinetra Engineering   Ultimech Industries  6.62
# 100016 2014-12-02         Optimech Solutions  Xelora Manufacturing 21.46
# 100017 2014-12-02        Kinetra Engineering    Trimech Industries 12.43
# 100018 2014-12-02       Jetronix Maintenance    Trimech Industries 18.99
# 100019 2014-12-02    Mechatronix Maintenance         Quantum Forge  0.00
# 100020 2014-12-02  Liftek Machinery Services   Yokentra Industries  5.56
#
#           S17   S16  AGE_OF_EQUIPMENT
# ID
# 99997  100.26  5.20            650.00
# ...

# %%
# dropna(how = 'all')
# baris yang memiliki missing values di setiap kolomnya akan di-drop.
equipment_missing.dropna(how='all')
# Out:
#              DATE         MAINTENANCE_VENDOR           MANUFACTURER   S15
# ID
# 99997  2014-11-30        Kinetra Engineering          Quantum Forge 19.26  \
# 100001 2014-12-02         Optimech Solutions    Yokentra Industries 11.09
# 100002 2014-12-02  Liftek Machinery Services  Rivatek Manufacturing 23.52
# 100003 2014-12-02  Liftek Machinery Services     Trimech Industries 11.13
# 100006 2014-12-02       Jetronix Maintenance     Steelon Industries 24.24
# 100007 2014-12-02          Novamech Services      Wahana Teknikindo 18.72
# 100009 2014-12-02    Mechatronix Maintenance   Xelora Manufacturing 25.64
# 100014 2014-12-02    Mechatronix Maintenance     Steelon Industries  6.29
# 100015 2014-12-02        Kinetra Engineering    Ultimech Industries  6.62
# 100016 2014-12-02         Optimech Solutions   Xelora Manufacturing 21.46
# 100017 2014-12-02        Kinetra Engineering     Trimech Industries 12.43
# 100018 2014-12-02       Jetronix Maintenance     Trimech Industries 18.99
# ...

# %%
# dropna(subset = ['AGE_OF_EQUIPMENT])
# baris yang AGE_OF_EQUIPMENT-nya missing akan di-drop
equipment_missing.dropna(subset=['AGE_OF_EQUIPMENT'])
# Out:
#              DATE         MAINTENANCE_VENDOR          MANUFACTURER   S15
# ID
# 99997  2014-11-30        Kinetra Engineering         Quantum Forge 19.26  \
# 100006 2014-12-02       Jetronix Maintenance    Steelon Industries 24.24
# 100007 2014-12-02          Novamech Services     Wahana Teknikindo 18.72
# 100009 2014-12-02    Mechatronix Maintenance  Xelora Manufacturing 25.64
# 100014 2014-12-02    Mechatronix Maintenance    Steelon Industries  6.29
# 100015 2014-12-02        Kinetra Engineering   Ultimech Industries  6.62
# 100016 2014-12-02         Optimech Solutions  Xelora Manufacturing 21.46
# 100017 2014-12-02        Kinetra Engineering    Trimech Industries 12.43
# 100018 2014-12-02       Jetronix Maintenance    Trimech Industries 18.99
# 100019 2014-12-02    Mechatronix Maintenance         Quantum Forge  0.00
# 100020 2014-12-02  Liftek Machinery Services   Yokentra Industries  5.56
#
#           S17   S16  AGE_OF_EQUIPMENT
# ID
# 99997  100.26  5.20            650.00
# ...

# %% [markdown]
# > ℹ️ Gunakan parameter `inplace = True` pada method `dropna()` untuk men-drop missing values di dataframe asli secara langsung tanpa perlu di-assign ulang.

# %% [markdown]
# #### Fill Missing Values (Imputation)

# %% [markdown]
# <span style="background-color:#DFF2BF; padding: 10px; border-radius: 5px; display: block;">
#
# **💡 Bagaimana Mengisi Missing Values dengan Tepat?**
#
# - **Kolom Kategori**
#     - Isi dengan nilai lain, misalnya "Other" dan "Missing".
#     - Isi dengan nilai mode.
#     - Method yang digunakan: `.fillna()`.
# - **Kolom Numerik**
#     - Isi dengan nilai mean atau median.
#     - Isi dengan nilai 0.
#     - Method yang digunakan: `.fillna()`.
# - **Kolom Datetime**
#     - Method `.bfill()`: untuk melakukan imputasi dari bawah ke atas.
#     - Method `.ffill()`: untuk melakukan imputasi dari atas ke bawah
#
# </span>

# %% [markdown]
# Mari kita lakukan proses imputasi dengan metode yang tepat.

# %% [markdown]
# **Kolom Kategori**

# %%
# fill missing values pada MAINTENANCE_VENDOR & MANUFACTURER dengan mode
equipment_missing['MAINTENANCE_VENDOR'] =equipment_missing['MAINTENANCE_VENDOR'].fillna(equipment_missing['MAINTENANCE_VENDOR'].mode()[0])
equipment_missing['MANUFACTURER'] =equipment_missing['MANUFACTURER'].fillna(equipment_missing['MANUFACTURER'].mode()[0])

# %% [markdown]
# **Kolom Numerik**

# %%
# fill missing values pada S15, S16 dan S17 dengan 0
equipment_missing['S15'] =  equipment_missing['S15'].fillna(0)
equipment_missing['S16'] =  equipment_missing['S16'].fillna(0)
equipment_missing['S17'] =  equipment_missing['S17'].fillna(0)

# %%
# fill missing values pada AGE_OF_EQUIPMENT dengan mean
equipment_missing['AGE_OF_EQUIPMENT'] = equipment_missing['AGE_OF_EQUIPMENT'].fillna(equipment_missing['AGE_OF_EQUIPMENT'].mean())

# %%
equipment_missing.isna().sum()
# Out:
# DATE                  6
# MAINTENANCE_VENDOR    0
# MANUFACTURER          0
# S15                   0
# S17                   0
# S16                   0
# AGE_OF_EQUIPMENT      0
# dtype: int64

# %% [markdown]
# **Kolom Datetime**

# %%
# cek imputasi datetime dengan .ffill()
equipment_missing['DATE'].fillna(method='ffill')
# Out:
# ID
# 99994           NaT
# 99995           NaT
# 99996           NaT
# 99997    2014-11-30
# 99998    2014-11-30
# 99999    2014-11-30
# 100000   2014-11-30
# 100001   2014-12-02
# 100002   2014-12-02
# 100003   2014-12-02
# 100006   2014-12-02
# 100007   2014-12-02
# 100009   2014-12-02
# 100014   2014-12-02
# 100015   2014-12-02
# 100016   2014-12-02
# 100017   2014-12-02
# 100018   2014-12-02
# 100019   2014-12-02
# 100020   2014-12-02
# Name: DATE, dtype: datetime64[ns]

# %%
# cek imputasi datetime dengan .bfill()
equipment_missing['DATE'].fillna(method='bfill')
# Out:
# ID
# 99994    2014-11-30
# 99995    2014-11-30
# 99996    2014-11-30
# 99997    2014-11-30
# 99998    2014-12-02
# 99999    2014-12-02
# 100000   2014-12-02
# 100001   2014-12-02
# 100002   2014-12-02
# 100003   2014-12-02
# 100006   2014-12-02
# 100007   2014-12-02
# 100009   2014-12-02
# 100014   2014-12-02
# 100015   2014-12-02
# 100016   2014-12-02
# 100017   2014-12-02
# 100018   2014-12-02
# 100019   2014-12-02
# 100020   2014-12-02
# Name: DATE, dtype: datetime64[ns]

# %%
# imputasi issue_date dengan metode yang tepat
equipment_missing['DATE'] = equipment_missing['DATE'].fillna(method='ffill').fillna(method='bfill')

# %%
# recheck missing values
equipment_missing.isna().sum()
# Out:
# DATE                  0
# MAINTENANCE_VENDOR    0
# MANUFACTURER          0
# S15                   0
# S17                   0
# S16                   0
# AGE_OF_EQUIPMENT      0
# dtype: int64

# %% [markdown]
# #### ☠️ **Masalah lain yang sering ada pada data**

# %% [markdown]
# 1. Format, penulisan, atau satuan data berbeda.
#
# - **Contoh:** Gender-> M vs Male vs m

# %%
data = {'gender': ['M', 'Male', 'm', 'F', 'Female', 'f']}
data = pd.DataFrame(data)

# %%
#code here
map_gender = {
    'L': 'Male',
    'P': 'Female',
    'M': 'Male',
    'F': 'Female',
    'f':'Female',
    'm':'Male',
    'Male':'Male',
    'Female':'Female'
}

# %%
data['gender'].map(map_gender)
# Out:
# 0      Male
# 1      Male
# 2      Male
# 3    Female
# 4    Female
# 5    Female
# Name: gender, dtype: object

# %% [markdown]
# 2. Kesalahan input pada kolom tertentu
#
# - **Contoh:** Terdapat data text pada kolom numerik

# %%
data = {'umur': [25, '30', 'tiga puluh', 40, '45a']}
df = pd.DataFrame(data)

# %%
#code here
df.astype({'umur':'string'}).replace({'umur':{'tiga puluh':'30','45a':'45'}})
# Out:
#   umur
# 0   25
# 1   30
# 2   30
# 3   40
# 4   45

# %% [markdown]
# ## Duplicated Values

# %% [markdown]
# > **Duplicated values** adalah kondisi di mana terdapat perulangan pada data dan biasanya kondisi ini tidak diinginkan.

# %% [markdown]
# ### Step 1: Check Duplicated Values

# %% [markdown]
# Untuk memeriksa apakah terdapat duplicated values, kita bisa menggunakan method `.duplicated()`.

# %%
# cek duplicated values
# simpan data ke variabel equipment
equipment_missing.duplicated()
# Out:
# ID
# 99994     False
# 99995      True
# 99996      True
# 99997     False
# 99998      True
# 99999      True
# 100000     True
# 100001    False
# 100002    False
# 100003    False
# 100006    False
# 100007    False
# 100009    False
# 100014    False
# 100015    False
# 100016    False
# 100017    False
# 100018    False
# 100019    False
# 100020    False
# dtype: bool

# %% [markdown]
# Untuk menghitung banyaknya duplicated values, kita dapat melanjutkan fungsi `.duplicated()` dengan `.sum()`.

# %%
# cek banyaknya duplicated values
equipment_missing.duplicated().sum()
# Out:
# 5

# %% [markdown]
# Dengan output di atas, terdapat 5 baris data yang record-nya sama dengan baris yang lain.

# %% [markdown]
# ❓ Apakah terdapat duplicated values pada dataframe `equipment` sebelumnya?

# %%
# cek duplicated values pada dataframe equipment
equipment.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 307746    False
# 307747    False
# 307748    False
# 307749    False
# 307750    False
# Length: 307751, dtype: bool

# %% [markdown]
# ### Step 2: Handle Duplicated Values

# %% [markdown]
# > Untuk menghapus duplicated values, kita dapat menggunakan method `.drop_duplicates()`.
#
# `.drop_duplicates()` bekerja sesuai parameter yang kita atur:

# %% [markdown]
# - `.drop_duplicates(keep = 'first')`: menghapus data duplikat, kecuali untuk kemunculan pertama.
# - `.drop_duplicates(keep = 'last')`: menghapus data duplikat, kecuali untuk kemunculan terakhir.

# %%
# drop_duplicates(keep = 'first')
equipment_missing.drop_duplicates(keep='first')
# Out:
#              DATE         MAINTENANCE_VENDOR           MANUFACTURER   S15
# ID
# 99994  2014-11-30        Kinetra Engineering     Trimech Industries  0.00  \
# 99997  2014-11-30        Kinetra Engineering          Quantum Forge 19.26
# 100001 2014-12-02         Optimech Solutions    Yokentra Industries 11.09
# 100002 2014-12-02  Liftek Machinery Services  Rivatek Manufacturing 23.52
# 100003 2014-12-02  Liftek Machinery Services     Trimech Industries 11.13
# 100006 2014-12-02       Jetronix Maintenance     Steelon Industries 24.24
# 100007 2014-12-02          Novamech Services      Wahana Teknikindo 18.72
# 100009 2014-12-02    Mechatronix Maintenance   Xelora Manufacturing 25.64
# 100014 2014-12-02    Mechatronix Maintenance     Steelon Industries  6.29
# 100015 2014-12-02        Kinetra Engineering    Ultimech Industries  6.62
# 100016 2014-12-02         Optimech Solutions   Xelora Manufacturing 21.46
# 100017 2014-12-02        Kinetra Engineering     Trimech Industries 12.43
# ...

# %%
# drop_duplicates(keep = 'last')
equipment_missing.drop_duplicates(keep='last')
# Out:
#              DATE         MAINTENANCE_VENDOR           MANUFACTURER   S15
# ID
# 99997  2014-11-30        Kinetra Engineering          Quantum Forge 19.26  \
# 100000 2014-11-30        Kinetra Engineering     Trimech Industries  0.00
# 100001 2014-12-02         Optimech Solutions    Yokentra Industries 11.09
# 100002 2014-12-02  Liftek Machinery Services  Rivatek Manufacturing 23.52
# 100003 2014-12-02  Liftek Machinery Services     Trimech Industries 11.13
# 100006 2014-12-02       Jetronix Maintenance     Steelon Industries 24.24
# 100007 2014-12-02          Novamech Services      Wahana Teknikindo 18.72
# 100009 2014-12-02    Mechatronix Maintenance   Xelora Manufacturing 25.64
# 100014 2014-12-02    Mechatronix Maintenance     Steelon Industries  6.29
# 100015 2014-12-02        Kinetra Engineering    Ultimech Industries  6.62
# 100016 2014-12-02         Optimech Solutions   Xelora Manufacturing 21.46
# 100017 2014-12-02        Kinetra Engineering     Trimech Industries 12.43
# ...

# %% [markdown]
# # 6. Text Mining & Processing 📑
#
# Text Mining adalah salah satu metode analisis data yang fokus utamanya adalah mencari informasi dan pola-pola dari data yang **tidak terstruktur, yaitu data teks**. Data teks disebut tidak terstruktur karena:
#
# - Satu kalimat terdiri dari beberapa kata yang jumlahnya berbeda-beda tiap kalimat.
# - Adanya *typo* (salah ketik), penyingkatan kata (you menjadi u), ataupun simbol-simbol tidak bermakna sehingga perlu dilakukan cleansing.
# - Adanya perbedaan bahasa yang digunakan sehingga perlu mencari kosa kata yang cocok.

# %% [markdown]
# ### Data Preparation
#
# **Read Data**
#
# Load `dataset_tweet_sentiment_cellular_service_provider.csv` menggunakan `pandas`

# %%
# code here
df_sentiment = pd.read_csv('data_input/dataset_tweet_sentiment_cellular_service_provider.csv')

# %% [markdown]
# ## Text Cleansing

# %% [markdown]
# *Text cleansing* adalah metode untuk membersihkan data teks dan membuatnya siap untuk memasukkan data ke model. Data teks berisi *noise* dalam berbagai bentuk seperti emoji, tanda baca, dan lain sebagainya.
#
# Proses *text cleansing* perlu dilakukan agar model nantinya dapat mempelajari informasi dari data sehingga dapat menghasilkan akurasi yang lebih baik.

# %% [markdown]
# **💬 Discussion**
#
# Menurut pendapat anda, dengan melihat data yang kita miliki, metode *text cleansing* apa saja kah yang sebaiknya dilakukan?
#
# **Jawab:**

# %% [markdown]
# **Library untuk pengolahan data text**

# %%
import nltk
from nltk.tokenize import sent_tokenize, word_tokenize, RegexpTokenizer,ToktokTokenizer
from string import punctuation
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Hanif\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Hanif\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %% [markdown]
# #### 1. Case Folding
#
# Case folding adalah suatu proses untuk menyeragamkan text pada dokumen. Pada text classification, case folding biasanya dilakukan dengan mengubah text menjadi **huruf kecil (lowercaseletters)**

# %%
df_sentiment
# Out:
#       Id Sentiment                                         Text Tweet
# 0      1  positive  <USER_MENTION> #BOIKOT_<PROVIDER_NAME> Gunakan...
# 1      2  positive  Saktinya balik lagi, alhamdulillah :v <PROVIDE...
# 2      3  negative  Selamat pagi <PROVIDER_NAME>  bisa bantu kenap...
# 3      4  negative  Dear <PROVIDER_NAME> akhir2 ini jaringan data ...
# 4      5  negative            Selamat malam PENDUSTA <PROVIDER_NAME>
# ..   ...       ...                                                ...
# 295  296  positive  Pantesan lancar ya, sinyal <PROVIDER_NAME> yan...
# 296  297  positive         Alhamdulillah lancar pakai <PROVIDER_NAME>
# 297  298  positive  Untung pakai internet <PROVIDER_NAME>, lancar,...
# 298  299  positive  di tempat ramai seperti di lokasi wisata, <PRO...
# 299  300  negative  Sinyal <PROVIDER_NAME> amsyong d stadion gajayana
#
# [300 rows x 3 columns]

# %%
df_sentiment['text_lower'] = df_sentiment['Text Tweet'].str.lower()

# %% [markdown]
# #### 2. Text Cleansing
#
# Tahapan text cleansing dapat dilakukan dengan cara **menghapus atribut data yang tidak diperlukan** seperti tanda baca (titik, koma, titik koma, kutipan, dan sebagainya) dan alamat Uniform Resource Locator (URL). Khusus untuk data Twitter, beberapa atribut lain tidak diperlukan dalam proses klasifikasi, yaitu karakter RT (re-tweet) dan username (nama akun yang menulis tweet). URL, RT/sebutan, dan nama produk dalam kumpulan data ini telah diganti dengan tag.
#
# Selamaproses text cleansing, biasanya kita menggunakan **reguler expression (regex)**. Berikut referensi untuk mempelajari tentang regex:
# > - https://www.w3schools.com/python/python_regex.asp
# > - https://regex101.com/

# %%
import re # regex
import string

# %%
text = "testes123 <provider_name> ..."
text.replace('<provider_name>', '')
# Out:
# 'testes123  ...'

# %%
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %% [markdown]
# Fungsi di bawah ini adalah fungsi yang dapat dikustomisasi berdasarkan konteks data teks yang digunakan.

# %%
# note: this function is customizable depends on your case
def text_cleansing(text):
    # remove tags
    text = text.replace('<provider_name>','')
    # remove non ASCII (emoticon, chinese word, etc)\
    text = text.encode('ascii','replace').decode('ascii')
    # remove digits (using regex) -> subtitute
    text = re.sub(r'\d+',' ',text)
    # remove punctuations (using regex)
    text = re.sub(r'[{}]'.format(string.punctuation),' ',text)
    # remove whitespace in the beginning and end of sentence
    text = text.strip()
    # remove extra whitespace in the middle of sentence (using regex)
    text = re.sub(r'\s+',' ',text)
    return text

# %% [markdown]
# Contoh implementasi fungsi `text_cleansing()` pada data `sample_text`

# %%
sample_text = df_sentiment['text_lower'][0]
sample_text
# Out:
# '<user_mention> #boikot_<provider_name> gunakan produk bangsa sendiri <provider_name>'

# %%
sample_text_clean = text_cleansing(sample_text)
sample_text_clean
# Out:
# 'user mention boikot gunakan produk bangsa sendiri'

# %% [markdown]
# Untuk mengimplementasikan pada dataframe, kita dapat menggunakan fungsi `.apply()`.

# %%
df_sentiment['text_clean'] = df_sentiment['text_lower'].apply(lambda x: text_cleansing(x))
df_sentiment.head()
# Out:
#    Id Sentiment                                         Text Tweet
# 0   1  positive  <USER_MENTION> #BOIKOT_<PROVIDER_NAME> Gunakan...  \
# 1   2  positive  Saktinya balik lagi, alhamdulillah :v <PROVIDE...
# 2   3  negative  Selamat pagi <PROVIDER_NAME>  bisa bantu kenap...
# 3   4  negative  Dear <PROVIDER_NAME> akhir2 ini jaringan data ...
# 4   5  negative            Selamat malam PENDUSTA <PROVIDER_NAME>
#
#                                           text_lower
# 0  <user_mention> #boikot_<provider_name> gunakan...  \
# 1  saktinya balik lagi, alhamdulillah :v <provide...
# 2  selamat pagi <provider_name>  bisa bantu kenap...
# 3  dear <provider_name> akhir2 ini jaringan data ...
# 4            selamat malam pendusta <provider_name>
#
#                                           text_clean
# 0  user mention boikot gunakan produk bangsa sendiri
# 1                saktinya balik lagi alhamdulillah v
# 2  selamat pagi bisa bantu kenapa di dalam kamar ...
# ...

# %% [markdown]
# #### 3. Text Normalization
#
# Text normalization digunakan untuk mengubah **bentuk kata informal menjadi formal**. Bentuk kata informal yang sering digunakan netizen Indonesia dalam menulis tweet antara lain:
#
# 1. kata-kata yang menunjukkan perasaan (misalnya hiks (sedih), wkwkwk/wkwk (tertawa), huhuhu (menangis), dan lain-lain);
# 2. pengulangan karakter untuk menonjolkan kata tertentu (misal: lamaaaa (lama), sorryyyyy (maaf), dan lain-lain);
# 3. penghilangan vokal (misalnya no (tidak), don't (jangan), dan lain-lain);
# 4. penggunaan kata-kata gaul (misal: ciyus (serius), dah (sudah), dan lain-lain);
# 5. penggantian huruf dengan angka (misal s4ya (me), disk0n (diskon), dan lain-lain).

# %%
# note: the dictionary is customizable depends on your case
normalized_word = pd.read_csv('data_input/new_kamusalay.csv', header=None)
data_dict = dict(zip(normalized_word[0], normalized_word[1]))
len(data_dict)
# Out:
# 15166

# %%
data_dict
# Out:
# {'anakjakartaasikasik': 'anak jakarta asyik asyik',
#  'pakcikdahtua': 'pak cik sudah tua',
#  'pakcikmudalagi': 'pak cik muda lagi',
#  't3tapjokowi': 'tetap jokowi',
#  '3x': 'tiga kali',
#  'aamiin': 'amin',
#  'aamiinn': 'amin',
#  'aamin': 'amin',
#  'aammiin': 'amin',
#  'abis': 'habis',
#  'abisin': 'habiskan',
#  'acau': 'kacau',
#  'achok': 'ahok',
#  'ad': 'ada',
#  'adek': 'adik',
#  'adl': 'adalah',
#  'adlah': 'adalah',
#  'adlh': 'adalah',
#  'ado': 'ada',
#  'aduhh': 'aduh',
#  'aer': 'air',
#  'afdol': 'afdal',
#  'agamaataualqur': 'agama alquran',
#  'agm': 'agama',
#  'agma': 'agama',
#  'ahaha': 'haha',
#  'ahahaha': 'haha',
#  'ahehehehe': 'hehe',
#  'ahir': 'akhir',
#  'ahirnya': 'akhirnya',
#  'ahk': 'ahok',
#  'ahlamdulillah': 'alhamdulillah',
#  'ahli2': 'para ahli',
#  'ahlusunnah': 'ahlus sunah',
#  'ahmaddani': 'ahmad dhani',
#  'aho': 'ahok',
#  'ahoax': 'ahok',
#  'ahoaxx': 'ahok',
#  'ahog': 'ahok',
#  'ahokataudjarot': 'ahok djarot',
# ...

# %%
def normalize_text(text):
    # temporary list
    result = []
    
    # split sentence into list of words
    split_text = text.split()
    
    # loop for each word
    for word in split_text:
        new_word = data_dict.get(word, word) # return normalized word if it exists in the dictionary
        result.append(new_word)
    
    # combine list of words into sentence
    combine_text = ' '.join(result)
    
    return combine_text

# %% [markdown]
# Mari kita cek perubahan sebelum dan sesudah dilakukan text normalisasi pada `sampe_text`

# %%
# before
sample_text_clean
# Out:
# 'bilboard iklan kok ada pesan tersembunyi boikot ramadhan url'

# %%
# after
sample_text_normalized = normalize_text(sample_text_clean)
sample_text_normalized
# Out:
# 'bilboard iklan kok ada pesan tersembunyi boikot ramadan uniform resource locator'

# %% [markdown]
# Implementasikan fungsi pada dataframe :

# %%
df_sentiment['text_normalized'] = df_sentiment['text_clean'].apply(lambda x: normalize_text(x))

# %%
df_sentiment.head()
# Out:
#    Id Sentiment                                         Text Tweet
# 0   1  positive  <USER_MENTION> #BOIKOT_<PROVIDER_NAME> Gunakan...  \
# 1   2  positive  Saktinya balik lagi, alhamdulillah :v <PROVIDE...
# 2   3  negative  Selamat pagi <PROVIDER_NAME>  bisa bantu kenap...
# 3   4  negative  Dear <PROVIDER_NAME> akhir2 ini jaringan data ...
# 4   5  negative            Selamat malam PENDUSTA <PROVIDER_NAME>
#
#                                           text_lower
# 0  <user_mention> #boikot_<provider_name> gunakan...  \
# 1  saktinya balik lagi, alhamdulillah :v <provide...
# 2  selamat pagi <provider_name>  bisa bantu kenap...
# 3  dear <provider_name> akhir2 ini jaringan data ...
# 4            selamat malam pendusta <provider_name>
#
#                                           text_clean
# 0  user mention boikot gunakan produk bangsa sendiri  \
# 1                saktinya balik lagi alhamdulillah v
# 2  selamat pagi bisa bantu kenapa di dalam kamar ...
# ...

# %% [markdown]
# #### 4. Stemming
#
# Stemming adalah proses pemotongan kata berimbuhan menjadi kata dasar. **Stemming bukanlah langkah wajib dalam text preprocessing.** Terkadang kita perlu melakukan stemming; kadang-kadang, kita tidak. Itu semua tergantung pada karakteristik data.
#
# > Kita menggunakan algoritma Nazief-Adriani (Adriani, et al., 2007) yang diimplementasikan menggunakan [Sastrawi Library](https://github.com/har07/PySastrawi)
#
# Stemming examples:
#
# - mencuci → cuci
# - berlari → lari
# - berlarian → lari
# - lari-larian → lari

# %%
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory

# create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# %%
# before
sample_text_normalized
# Out:
# 'bilboard iklan kok ada pesan tersembunyi boikot ramadan uniform resource locator'

# %%
# after
sample_text_stemmed = stemmer.stem(sample_text_normalized)
sample_text_stemmed
# Out:
# 'bilboard iklan kok ada pesan sembunyi boikot ramadan uniform resource locator'

# %% [markdown]
# Implementasikan fungsi pada dataframe :

# %%
df_sentiment['text_stemmed'] = df_sentiment['text_normalized'].apply(lambda x: stemmer.stem(x))
df_sentiment.head()
# Out:
#    Id Sentiment                                         Text Tweet
# 0   1  positive  <USER_MENTION> #BOIKOT_<PROVIDER_NAME> Gunakan...  \
# 1   2  positive  Saktinya balik lagi, alhamdulillah :v <PROVIDE...
# 2   3  negative  Selamat pagi <PROVIDER_NAME>  bisa bantu kenap...
# 3   4  negative  Dear <PROVIDER_NAME> akhir2 ini jaringan data ...
# 4   5  negative            Selamat malam PENDUSTA <PROVIDER_NAME>
#
#                                           text_lower
# 0  <user_mention> #boikot_<provider_name> gunakan...  \
# 1  saktinya balik lagi, alhamdulillah :v <provide...
# 2  selamat pagi <provider_name>  bisa bantu kenap...
# 3  dear <provider_name> akhir2 ini jaringan data ...
# 4            selamat malam pendusta <provider_name>
#
#                                           text_clean
# 0  user mention boikot gunakan produk bangsa sendiri  \
# 1                saktinya balik lagi alhamdulillah v
# 2  selamat pagi bisa bantu kenapa di dalam kamar ...
# ...

# %% [markdown]
# #### 5. Stopwords Removal
#
# Menghapus text yang tidak bermakna seperti kata penguhubung dan lainnya.
#
# > Kita menggunakan daftar [stopwords Bahasa Indonesia](https://github.com/masdevid/ID-Stopwords) yang diperoleh dari penelitian  [Tala (2003)](https://www.semanticscholar.org/paper/A-Study-of-Stemming-Effects-on-Information-in-Tala/8ed9c7d54fd3f0b1ce3815b2eca82147b771ca8f?p2df) karena stopword lebih banyak dari daftar stopword di library nltk bahasa Indonesia.

# %%
from nltk.tokenize import word_tokenize 
from nltk.corpus import stopwords

# get stopword indonesia
list_stopwords = stopwords.words('indonesian')
len(list_stopwords)
# Out:
# 758

# %%
stopwords_tala = pd.read_csv('data_input/StopWords_Tala.csv')
list_stopwords = set(stopwords_tala['LEMA'])
len(list_stopwords)
# Out:
# 44019

# %%
list_stopwords
# Out:
# {'kerjajalan',
#  'fendii',
#  'kerawamagun',
#  'ojolv',
#  'sgen',
#  'isangan',
#  'jebskkan',
#  'ygvga',
#  'teti',
#  'stopby',
#  'sirrul',
#  'jonni',
#  'halogeen',
#  'garasiatassaluran',
#  'menkmati',
#  'beristirahatnya',
#  'ditladadicekhilang',
#  'pkmconfusion',
#  'respondingnya',
#  'aedi',
#  'tigaconfusionawalnya',
#  'badui',
#  'sayamau',
#  'benyek',
#  'sepantasnyalah',
#  'pemandangann',
#  'sg',
#  'dimodif',
#  'pengumpulanorang',
#  'lrang',
#  'fachriza',
#  'tima',
#  'sigapconfusion',
#  'setempatada',
#  'nander',
#  'permail',
#  'radhan',
#  'makangajiaibon',
#  'kbrin',
#  'gogor',
#  'berain',
#  'tulangnya',
#  'batubraya',
#  'timuntas',
#  'elteha',
#  'hananto',
#  'ziadatul',
#  'ayi',
#  'kentardysutjiadi',
#  'mendapatkan',
#  'harapanconfusion',
#  'diperempat',
#  'ze',
#  'dubant',
#  'bisamenjamur',
#  'pengangan',
#  'menyembakan',
#  'antisifasi',
#  'kemungkingan',
#  'tunts',
#  'plprn',
#  'suburnya',
#  'abar',
#  'nonmotor',
# ...

# %% [markdown]
# Fungsi untuk stopwords :

# %%
def remove_stopwords(text):
    # temporary list
    result = []
    
    # split sentence into list of words
    split_text = text.split()
    
    # loop for each word
    for word in split_text:
        if word not in list_stopwords:
            result.append(word) # append word that not in stopwords list
            
    # combine list of words into sentence
    combine_text = ' '.join(result)

    return combine_text

# %%
# before
sample_text_stemmed
# Out:
# 'bilboard iklan kok ada pesan sembunyi boikot ramadan uniform resource locator'

# %%
# after
sample_text_stopword_removed = remove_stopwords(sample_text_stemmed)
sample_text_stopword_removed
# Out:
# 'bilboard iklan pesan sembunyi boikot ramadan locator'

# %% [markdown]
# Implementasikan fungsi pada dataframe :

# %%
df_sentiment['text_no_stopwords'] = df_sentiment['text_stemmed'].apply(lambda x: remove_stopwords(x))

# %% [markdown]
# Semua tahapan data pre-processing sudah dilakukan. Untuk perubahan di setiap step nya, sudah dilampirkan dalam setiap kolom dokumentasi. Hal ini agar memudahkan untuk melihat perbedaan di setiap tahapan pre-processing.

# %%
df_sentiment.head()
# Out:
#    Id Sentiment                                         Text Tweet
# 0   1  positive  <USER_MENTION> #BOIKOT_<PROVIDER_NAME> Gunakan...  \
# 1   2  positive  Saktinya balik lagi, alhamdulillah :v <PROVIDE...
# 2   3  negative  Selamat pagi <PROVIDER_NAME>  bisa bantu kenap...
# 3   4  negative  Dear <PROVIDER_NAME> akhir2 ini jaringan data ...
# 4   5  negative            Selamat malam PENDUSTA <PROVIDER_NAME>
#
#                                           text_lower
# 0  <user_mention> #boikot_<provider_name> gunakan...  \
# 1  saktinya balik lagi, alhamdulillah :v <provide...
# 2  selamat pagi <provider_name>  bisa bantu kenap...
# 3  dear <provider_name> akhir2 ini jaringan data ...
# 4            selamat malam pendusta <provider_name>
#
#                                           text_clean
# 0  user mention boikot gunakan produk bangsa sendiri  \
# 1                saktinya balik lagi alhamdulillah v
# 2  selamat pagi bisa bantu kenapa di dalam kamar ...
# ...

# %% [markdown]
# **🔎 Knowledge Check**

# %% [markdown]
# 1. Berikut ini adalah salah satu teknik text-processing yang tidak mengurangi dimensi pada data adalah..
# - [ ] Menghapus stopwords
# - [ ] Normalisasi text
# - [ ] Case Foldings
#
# 2. Langkah pertama dalam preprocessing teks ini adalah mengubah semua teks menjadi huruf kecil (lowercasing). Mengapa langkah ini penting?
#
# - [ ] mengurangi variasi data yang disebabkan oleh perbedaan kapitalisasi
# - [ ] menghapus kata-kata tidak penting dari teks
# - [ ] membuat teks lebih mudah diproses oleh model
#
# 2. Dalam proses preprocessing teks, mengapa kita sering melakukan penghapusan stopwords?
#
# - [ ] menghilangkan kata-kata umum yang tidak memberikan nilai informasi yang signifikan
# - [ ] memastikan teks tidak mengandung angka atau simbol khusus -> regex
# - [ ] mengurangi panjang teks sehingga lebih mudah disimpan di database
# - [ ] mengganti kata-kata panjang dengan singkatan.

# %% [markdown]
# ### Exploratory Data Analysis

# %% [markdown]
# **1. Count Unique Words**

# %%
from collections import Counter

# function to count unique words
def counter_word(text):
    count = Counter()
    for sentence in text.values:
        for word in sentence.split():
            count[word] += 1
    return count

# %%
# find out how many unique words in our data
unique_words = counter_word(df_sentiment['text_stemmed'])
len(unique_words)
# Out:
# 795

# %%
# take a look at the five most common words
unique_words.most_common(5)
# Out:
# [('tidak', 113), ('di', 62), ('pakai', 54), ('yang', 53), ('uniform', 49)]

# %% [markdown]
# Pada tahapan EDA, kita juga akan membuat visualisasi `wordcloud` untuk mengetahui kata yang sering muncul pada masing-masing sentiment baik `negative` maupun `positive`.

# %% [markdown]
# **2. Wordcloud Sentiment Positive**

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud

plt.figure(figsize = (15,15))
wc = WordCloud(background_color="white", width = 1600 , height = 800 , max_words = 3000).generate(" ".join(df_sentiment[df_sentiment['Sentiment'] == 'positive'].text_no_stopwords))
plt.imshow(wc , interpolation = 'bilinear')

# %% [markdown]
# **2. Wordcloud Sentiment Negaive**

# %%
plt.figure(figsize = (15,15))
wc = WordCloud(background_color="white", width = 1600 , height = 800 , max_words = 3000).generate(" ".join(df_sentiment[df_sentiment['Sentiment'] == 'negative'].text_no_stopwords))
plt.imshow(wc , interpolation = 'bilinear')
