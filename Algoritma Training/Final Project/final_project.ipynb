# %% [markdown]
# # Business Understanding

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('marine_engine_data.csv')

# %%
df
# Out:
#       timestamp engine_id  engine_temp  oil_pressure  fuel_consumption
# 0    2023-01-01   ENG_001    79.816406      7.049409       1000.000000  \
# 1    2023-01-08   ENG_001    98.982068      8.000000       6308.623817
# 2    2023-01-15   ENG_001    83.918153      8.000000       6444.402260
# 3    2023-01-22   ENG_001    81.887081      7.601603       4439.946613
# 4    2023-01-29   ENG_001    78.550429      6.233033       3146.234038
# ...         ...       ...          ...           ...               ...
# 5195 2024-11-24   ENG_050    92.745290      7.956103       7680.773408
# 5196 2024-12-01   ENG_050    89.462079      8.000000       1265.703232
# 5197 2024-12-08   ENG_050    79.057910      6.413932       4052.497442
# 5198 2024-12-15   ENG_050    79.379851      7.437593       1000.000000
# 5199 2024-12-22   ENG_050    78.091169      7.137819       3589.190365
#
#       vibration_level          rpm  engine_load  coolant_temp  exhaust_temp
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5200 entries, 0 to 5199
# Data columns (total 17 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   timestamp                  5200 non-null   object
#  1   engine_id                  5200 non-null   object
#  2   engine_temp                5200 non-null   float64
#  3   oil_pressure               5200 non-null   float64
#  4   fuel_consumption           5200 non-null   float64
#  5   vibration_level            5200 non-null   float64
#  6   rpm                        5200 non-null   float64
#  7   engine_load                5200 non-null   float64
#  8   coolant_temp               5200 non-null   float64
#  9   exhaust_temp               5200 non-null   float64
#  10  running_period             5200 non-null   float64
#  11  fuel_consumption_per_hour  5200 non-null   float64
#  12  maintenance_status         5200 non-null   object
# ...

# %%
df['timestamp'] = pd.to_datetime(df['timestamp'])
df['maintenance_status'] = df['maintenance_status'].astype('category')
df['failure_mode'] = df['failure_mode'].astype('category')
df['fuel_type'] = df['fuel_type'].astype('category')
df['manufacturer'] = df['manufacturer'].astype('category')
df['engine_type'] = df['engine_type'].astype('category')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5200 entries, 0 to 5199
# Data columns (total 17 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   timestamp                  5200 non-null   datetime64[ns]
#  1   engine_id                  5200 non-null   object
#  2   engine_temp                5200 non-null   float64
#  3   oil_pressure               5200 non-null   float64
#  4   fuel_consumption           5200 non-null   float64
#  5   vibration_level            5200 non-null   float64
#  6   rpm                        5200 non-null   float64
#  7   engine_load                5200 non-null   float64
#  8   coolant_temp               5200 non-null   float64
#  9   exhaust_temp               5200 non-null   float64
#  10  running_period             5200 non-null   float64
#  11  fuel_consumption_per_hour  5200 non-null   float64
#  12  maintenance_status         5200 non-null   category
# ...

# %%
df.describe()
# Out:
#                  timestamp  engine_temp  oil_pressure  fuel_consumption
# count                 5200  5200.000000   5200.000000       5200.000000  \
# mean   2023-12-27 12:00:00    85.067979      7.281496       3937.674530
# min    2023-01-01 00:00:00    60.524875      5.000000       1000.000000
# 25%    2023-06-30 06:00:00    79.895619      6.723802       1880.183832
# 50%    2023-12-27 12:00:00    85.043649      7.484437       3458.765539
# 75%    2024-06-24 18:00:00    90.284900      8.000000       5579.230554
# max    2024-12-22 00:00:00   107.357690      8.000000      12672.543097
# std                    NaN     7.244281      0.750153       2439.427599
#
#        vibration_level          rpm  engine_load  coolant_temp  exhaust_temp
# count      5200.000000  5200.000000  5200.000000   5200.000000   5200.000000  \
# mean          3.746574  1496.909900    49.794979     85.000245    449.829456
# min           2.500000   732.668890    20.000698     70.000000    426.124325
# ...

# %%
df.describe(include='category')
# Out:
#           maintenance_status failure_mode          engine_type fuel_type
# count                   5200         5200                 5200      5200  \
# unique                     3            4                    4         2
# top     Requires Maintenance  Oil Leakage  4-stroke High-Speed    Diesel
# freq                    1756         1605                 1548      3084
#
#        manufacturer
# count          5200
# unique            6
# top         MAN B&W
# freq           1562

# %%
df.describe(include='object')
# Out:
#        engine_id
# count       5200
# unique        50
# top      ENG_001
# freq         104

# %%
df = df.drop(columns=['timestamp', 'engine_id'])

# %%
df['is_target'] = df['maintenance_status'].apply(lambda x: 1 if x in ['Requires Maintenance','Critical'] else 0)

# %%
df[['is_target','maintenance_status']].value_counts()
# Out:
# is_target  maintenance_status
# 1          Requires Maintenance    1756
#            Critical                1740
# 0          Normal                  1704
# Name: count, dtype: int64

# %%
df.count()
# Out:
# engine_temp                  5200
# oil_pressure                 5200
# fuel_consumption             5200
# vibration_level              5200
# rpm                          5200
# engine_load                  5200
# coolant_temp                 5200
# exhaust_temp                 5200
# running_period               5200
# fuel_consumption_per_hour    5200
# maintenance_status           5200
# failure_mode                 5200
# engine_type                  5200
# fuel_type                    5200
# manufacturer                 5200
# is_target                    5200
# dtype: int64
