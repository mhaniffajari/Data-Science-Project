# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ## Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('flight.csv')

# %%
def preprocessing(df):
    """"
    Objective :
    Function for preprocessing data, known missing, duplicated values and basic stastics every column in dataframe and duplicated row
    df is dataframe
    """
    try:
        import pandas as pd
        variables = pd.DataFrame(columns=['Variable','Number of unique values','Percent of Null(%)','Number of Null','Type','Values'])
        for i, var in enumerate(df.columns):
            variables.loc[i] = [var, df[var].nunique(),df[var].isnull().sum()/df.shape[0]*100,df[var].isnull().sum(),df[var].dtypes,df[var].unique()]
        return (variables.set_index('Variable'))
    except:
        print('ada kesalahan penginputan')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62988 entries, 0 to 62987
# Data columns (total 23 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   MEMBER_NO          62988 non-null  int64
#  1   FFP_DATE           62988 non-null  object
#  2   FIRST_FLIGHT_DATE  62988 non-null  object
#  3   GENDER             62985 non-null  object
#  4   FFP_TIER           62988 non-null  int64
#  5   WORK_CITY          60719 non-null  object
#  6   WORK_PROVINCE      59740 non-null  object
#  7   WORK_COUNTRY       62962 non-null  object
#  8   AGE                62568 non-null  float64
#  9   LOAD_TIME          62988 non-null  object
#  10  FLIGHT_COUNT       62988 non-null  int64
#  11  BP_SUM             62988 non-null  int64
#  12  SUM_YR_1           62437 non-null  float64
#  13  SUM_YR_2           62850 non-null  float64
#  14  SEG_KM_SUM         62988 non-null  int64
#  15  LAST_FLIGHT_DATE   62988 non-null  object
#  16  LAST_TO_END        62988 non-null  int64
#  17  AVG_INTERVAL       62988 non-null  float64
#  18  MAX_INTERVAL       62988 non-null  int64
#  19  EXCHANGE_COUNT     62988 non-null  int64
#  20  avg_discount       62988 non-null  float64
#  21  Points_Sum         62988 non-null  int64
#  22  Point_NotFlight    62988 non-null  int64
# dtypes: float64(5), int64(10), object(8)
# memory usage: 11.1+ MB

# %% [markdown]
# ## Checking Duplicated Data

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.duplicated(subset='MEMBER_NO').sum()
# Out:
# 0

# %% [markdown]
# ## Checking Null Values

# %%
preprocessing(df)
# Out:
#                   Number of unique values  Percent of Null(%) Number of Null  \
# Variable
# MEMBER_NO                           62988            0.000000              0
# FFP_DATE                             3068            0.000000              0
# FIRST_FLIGHT_DATE                    3406            0.000000              0
# GENDER                                  2            0.004763              3
# FFP_TIER                                3            0.000000              0
# WORK_CITY                            3234            3.602273           2269
# WORK_PROVINCE                        1165            5.156538           3248
# WORK_COUNTRY                          118            0.041278             26
# AGE                                    84            0.666794            420
# LOAD_TIME                               1            0.000000              0
# FLIGHT_COUNT                          153            0.000000              0
# BP_SUM                              23449            0.000000              0
# SUM_YR_1                            15828            0.874770            551
# SUM_YR_2                            16767            0.219089            138
# SEG_KM_SUM                          29081            0.000000              0
# LAST_FLIGHT_DATE                      731            0.000000              0
# LAST_TO_END                           731            0.000000              0
# AVG_INTERVAL                        10706            0.000000              0
# MAX_INTERVAL                          706            0.000000              0
# EXCHANGE_COUNT                         28            0.000000              0
# avg_discount                        54179            0.000000              0
# Points_Sum                          25062            0.000000              0
# Point_NotFlight                        99            0.000000              0
#
#                       Type                                             Values
# Variable
# MEMBER_NO            int64  [54993, 28065, 55106, 21189, 39546, 56972, 449...
# FFP_DATE            object  [11/2/2006, 2/19/2007, 2/1/2007, 8/22/2008, 4/...
# FIRST_FLIGHT_DATE   object  [12/24/2008, 8/3/2007, 8/30/2007, 8/23/2008, 4...
# GENDER              object                                [Male, Female, nan]
# FFP_TIER             int64                                          [6, 5, 4]
# WORK_CITY           object  [., nan, Los Angeles, guiyang, guangzhou, wulu...
# WORK_PROVINCE       object  [beijing, CA, guizhou, guangdong, xinjiang, zh...
# WORK_COUNTRY        object  [CN, US, FR, AN, JP, HK, MY, AU, NL, MX, CA, K...
# AGE                float64  [31.0, 42.0, 40.0, 64.0, 48.0, 46.0, 50.0, 43....
# LOAD_TIME           object                                        [3/31/2014]
# FLIGHT_COUNT         int64  [210, 140, 135, 23, 152, 92, 101, 73, 56, 64, ...
# BP_SUM               int64  [505308, 362480, 351159, 337314, 273844, 31333...
# SUM_YR_1           float64  [239560.0, 171483.0, 163618.0, 116350.0, 12456...
# SUM_YR_2           float64  [234188.0, 167434.0, 164982.0, 125500.0, 13070...
# SEG_KM_SUM           int64  [580717, 293678, 283712, 281336, 309928, 29458...
# LAST_FLIGHT_DATE    object  [3/31/2014, 3/25/2014, 3/21/2014, 12/26/2013, ...
# LAST_TO_END          int64  [1, 7, 11, 97, 5, 79, 3, 6, 15, 22, 67, 2, 65,...
# AVG_INTERVAL       float64  [3.483253589, 5.194244604, 5.298507463, 27.863...
# MAX_INTERVAL         int64  [18, 17, 73, 47, 52, 28, 45, 94, 95, 42, 112, ...
# EXCHANGE_COUNT       int64  [34, 29, 20, 11, 27, 10, 7, 5, 13, 1, 15, 3, 1...
# avg_discount       float64  [0.961639043, 1.25231444, 1.254675516, 1.09086...
# Points_Sum           int64  [619760, 415768, 406361, 372204, 338813, 34312...
# Point_NotFlight      int64  [50, 33, 26, 12, 39, 15, 29, 14, 7, 16, 3, 66,...

# %%
cat = ['GENDER','WORK_PROVINCE','WORK_COUNTRY','WORK_CITY']
numeric = ['AGE','FLIGHT_COUNT','BP_SUM','SUM_YR_1','SUM_YR_2','SEG_KM_SUM',
      'LAST_TO_END','AVG_INTERVAL','MAX_INTERVAL','EXCHANGE_COUNT',
      'avg_discount','Points_Sum','Point_NotFlight']

# %% [markdown]
# **Data Insight**
#
#     1. GENDER, WORK_CITY, WORK_PROVINCE, WORK_COUNTRY, AGE, SUM_YR_1,SUM_YR_2 mempunyai null value
#     2. Data yang mengandung tanggal dapat diubah menjadi datetime
#     3. WORK_PROVINCE, WORK_CITY, WORK_COUNTRY memiliki High Cardinality

# %%
df['FFP_DATE'] = pd.to_datetime(df['FFP_DATE'])
df['FIRST_FLIGHT_DATE'] = pd.to_datetime(df['FIRST_FLIGHT_DATE'])

# %%
df['LAST_FLIGHT_DATE'] = df['LAST_FLIGHT_DATE'].str.replace('2014/2/29','2014/2/28')

# %% [markdown]
# ada salah penulisan tanggal pada kolom LAST_FLIGHT_DATE

# %%
df['LAST_FLIGHT_DATE'] = pd.to_datetime(df['LAST_FLIGHT_DATE'])

# %%
df['LOAD_TIME'] = pd.to_datetime(df['LOAD_TIME'])

# %% [markdown]
# ## Descriptitve Analysis

# %%
df.describe()
# Out:
#           MEMBER_NO      FFP_TIER           AGE  FLIGHT_COUNT         BP_SUM  \
# count  62988.000000  62988.000000  62568.000000  62988.000000   62988.000000
# mean   31494.500000      4.102162     42.476346     11.839414   10925.081254
# std    18183.213715      0.373856      9.885915     14.049471   16339.486151
# min        1.000000      4.000000      6.000000      2.000000       0.000000
# 25%    15747.750000      4.000000     35.000000      3.000000    2518.000000
# 50%    31494.500000      4.000000     41.000000      7.000000    5700.000000
# 75%    47241.250000      4.000000     48.000000     15.000000   12831.000000
# max    62988.000000      6.000000    110.000000    213.000000  505308.000000
#
#             SUM_YR_1       SUM_YR_2     SEG_KM_SUM   LAST_TO_END  \
# count   62437.000000   62850.000000   62988.000000  62988.000000
# mean     5355.376064    5604.026014   17123.878691    176.120102
# std      8109.450147    8703.364247   20960.844623    183.822223
# min         0.000000       0.000000     368.000000      1.000000
# 25%      1003.000000     780.000000    4747.000000     29.000000
# 50%      2800.000000    2773.000000    9994.000000    108.000000
# 75%      6574.000000    6845.750000   21271.250000    268.000000
# max    239560.000000  234188.000000  580717.000000    731.000000
#
#        AVG_INTERVAL  MAX_INTERVAL  EXCHANGE_COUNT  avg_discount   Points_Sum  \
# count  62988.000000  62988.000000    62988.000000  62988.000000   62988.0000
# mean      67.749788    166.033895        0.319775      0.721558   12545.7771
# std       77.517866    123.397180        1.136004      0.185427   20507.8167
# min        0.000000      0.000000        0.000000      0.000000       0.0000
# 25%       23.370370     79.000000        0.000000      0.611997    2775.0000
# 50%       44.666667    143.000000        0.000000      0.711856    6328.5000
# 75%       82.000000    228.000000        0.000000      0.809476   14302.5000
# max      728.000000    728.000000       46.000000      1.500000  985572.0000
#
#        Point_NotFlight
# count     62988.000000
# mean          2.728155
# std           7.364164
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           1.000000
# max         140.000000

# %% [markdown]
# **Data Insight**
#
#     1. nilai max AGE ada yang mencapai 110 tahun
#     2. Total data yang dimiliki adalah 62988

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('flight.csv')

# %%
def preprocessing(df):
    """"
    Objective :
    Function for preprocessing data, known missing, duplicated values and basic stastics every column in dataframe and duplicated row
    df is dataframe
    """
    try:
        import pandas as pd
        variables = pd.DataFrame(columns=['Variable','Number of unique values','Percent of Null(%)','Number of Null','Type','Values'])
        for i, var in enumerate(df.columns):
            variables.loc[i] = [var, df[var].nunique(),df[var].isnull().sum()/df.shape[0]*100,df[var].isnull().sum(),df[var].dtypes,df[var].unique()]
        return (variables.set_index('Variable'))
    except:
        print('ada kesalahan penginputan')

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.duplicated(subset='MEMBER_NO').sum()
# Out:
# 0

# %%
preprocessing(df)
# Out:
#                   Number of unique values  Percent of Null(%) Number of Null  \
# Variable
# MEMBER_NO                           62988            0.000000              0
# FFP_DATE                             3068            0.000000              0
# FIRST_FLIGHT_DATE                    3406            0.000000              0
# GENDER                                  2            0.004763              3
# FFP_TIER                                3            0.000000              0
# WORK_CITY                            3234            3.602273           2269
# WORK_PROVINCE                        1165            5.156538           3248
# WORK_COUNTRY                          118            0.041278             26
# AGE                                    84            0.666794            420
# LOAD_TIME                               1            0.000000              0
# FLIGHT_COUNT                          153            0.000000              0
# BP_SUM                              23449            0.000000              0
# SUM_YR_1                            15828            0.874770            551
# SUM_YR_2                            16767            0.219089            138
# SEG_KM_SUM                          29081            0.000000              0
# LAST_FLIGHT_DATE                      731            0.000000              0
# LAST_TO_END                           731            0.000000              0
# AVG_INTERVAL                        10706            0.000000              0
# MAX_INTERVAL                          706            0.000000              0
# EXCHANGE_COUNT                         28            0.000000              0
# avg_discount                        54179            0.000000              0
# Points_Sum                          25062            0.000000              0
# Point_NotFlight                        99            0.000000              0
#
#                       Type                                             Values
# Variable
# MEMBER_NO            int64  [54993, 28065, 55106, 21189, 39546, 56972, 449...
# FFP_DATE            object  [11/2/2006, 2/19/2007, 2/1/2007, 8/22/2008, 4/...
# FIRST_FLIGHT_DATE   object  [12/24/2008, 8/3/2007, 8/30/2007, 8/23/2008, 4...
# GENDER              object                                [Male, Female, nan]
# FFP_TIER             int64                                          [6, 5, 4]
# WORK_CITY           object  [., nan, Los Angeles, guiyang, guangzhou, wulu...
# WORK_PROVINCE       object  [beijing, CA, guizhou, guangdong, xinjiang, zh...
# WORK_COUNTRY        object  [CN, US, FR, AN, JP, HK, MY, AU, NL, MX, CA, K...
# AGE                float64  [31.0, 42.0, 40.0, 64.0, 48.0, 46.0, 50.0, 43....
# LOAD_TIME           object                                        [3/31/2014]
# FLIGHT_COUNT         int64  [210, 140, 135, 23, 152, 92, 101, 73, 56, 64, ...
# BP_SUM               int64  [505308, 362480, 351159, 337314, 273844, 31333...
# SUM_YR_1           float64  [239560.0, 171483.0, 163618.0, 116350.0, 12456...
# SUM_YR_2           float64  [234188.0, 167434.0, 164982.0, 125500.0, 13070...
# SEG_KM_SUM           int64  [580717, 293678, 283712, 281336, 309928, 29458...
# LAST_FLIGHT_DATE    object  [3/31/2014, 3/25/2014, 3/21/2014, 12/26/2013, ...
# LAST_TO_END          int64  [1, 7, 11, 97, 5, 79, 3, 6, 15, 22, 67, 2, 65,...
# AVG_INTERVAL       float64  [3.483253589, 5.194244604, 5.298507463, 27.863...
# MAX_INTERVAL         int64  [18, 17, 73, 47, 52, 28, 45, 94, 95, 42, 112, ...
# EXCHANGE_COUNT       int64  [34, 29, 20, 11, 27, 10, 7, 5, 13, 1, 15, 3, 1...
# avg_discount       float64  [0.961639043, 1.25231444, 1.254675516, 1.09086...
# Points_Sum           int64  [619760, 415768, 406361, 372204, 338813, 34312...
# Point_NotFlight      int64  [50, 33, 26, 12, 39, 15, 29, 14, 7, 16, 3, 66,...

# %%
cat = ['GENDER','WORK_PROVINCE','WORK_COUNTRY','WORK_CITY']
numeric = ['AGE','FLIGHT_COUNT','BP_SUM','SUM_YR_1','SUM_YR_2','SEG_KM_SUM',
      'LAST_TO_END','AVG_INTERVAL','MAX_INTERVAL','EXCHANGE_COUNT',
      'avg_discount','Points_Sum','Point_NotFlight']

# %% [markdown]
# **Data Insight**
#
#     1. GENDER, WORK_CITY, WORK_PROVINCE, WORK_COUNTRY, AGE, SUM_YR_1,SUM_YR_2 mempunyai null value
#     2. Data yang mengandung tanggal dapat diubah menjadi datetime
#     3. WORK_PROVINCE, WORK_CITY, WORK_COUNTRY memiliki High Cardinality

# %%
df['FFP_DATE'] = pd.to_datetime(df['FFP_DATE'])
df['FIRST_FLIGHT_DATE'] = pd.to_datetime(df['FIRST_FLIGHT_DATE'])

# %%
df['LAST_FLIGHT_DATE'] = df['LAST_FLIGHT_DATE'].str.replace('2014/2/29','2014/2/28')

# %% [markdown]
# ada salah penulisan tanggal pada kolom LAST_FLIGHT_DATE

# %%
df['LAST_FLIGHT_DATE'] = pd.to_datetime(df['LAST_FLIGHT_DATE'])

# %%
df[cat].describe()
# Out:
#        GENDER WORK_PROVINCE WORK_COUNTRY  WORK_CITY
# count   62985         59740        62962      60719
# unique      2          1165          118       3234
# top      Male     guangdong           CN  guangzhou
# freq    48134         17509        57748       9386

# %%
df[['FIRST_FLIGHT_DATE','LAST_FLIGHT_DATE']].describe()
# Out:
#           FIRST_FLIGHT_DATE     LAST_FLIGHT_DATE
# count                 62988                62988
# unique                 3406                  730
# top     2013-02-16 00:00:00  2014-03-31 00:00:00
# freq                     96                  959
# first   1905-12-31 00:00:00  2012-04-01 00:00:00
# last    2015-05-30 00:00:00  2014-03-31 00:00:00

# %% [markdown]
# **Data Insight**
#
# penerbangan pertama ada yang tahun 1905

# %% [markdown]
# # Distribusi Numerik

# %% [markdown]
# ## Distribusi Plot

# %%
    for j in range (0,len(numeric)):
        num = numeric[j]
        sns.kdeplot(x=df[num])
        plt.figure(figsize=(3,3))
        plt.show()

# %% [markdown]
# **Data Insight**
#
# 1. distribusi kolom rata-rata memiliki skew positive yang ekstrim

# %% [markdown]
# ## Box Plot

# %%
    for j in range (0,len(numeric)):
        num = numeric[j]
        sns.boxplot(y=df[num])
        plt.figure(figsize=(3,3))
        plt.show()

# %% [markdown]
# banyak kolom yang memiliki outlier ekstrim

# %%
df.shape[0]
# Out:
# 62988

# %%
df['WORK_PROVINCE'].value_counts().head(20)
# Out:
# guangdong         17509
# beijing            8014
# shanghai           4998
# liaoning           4182
# xinjiang           2512
# jilin              1823
# heilongjiang       1429
# hubei              1377
# henan              1187
# jiangsu            1113
# zhejiang           1052
# .                   930
# hunan               927
# liaoningsheng       900
# guangdongsheng      815
# shandong            722
# fujian              709
# guangxi             538
# jilinsheng          535
# sichuan             527
# Name: WORK_PROVINCE, dtype: int64

# %%
df['WORK_CITY'].value_counts().head(20)
# Out:
# guangzhou       9386
# beijing         7845
# shanghai        5001
# shenzhen        3605
# dalian          1979
# shenyang        1626
# changchun       1528
# wulumuqi        1471
# wuhan           1156
# haerbin          945
# guangzhoushi     942
# shenyangshi      827
# zhengzhou        750
# .                667
# changsha         640
# foshan           627
# dongguan         539
# zhuhai           522
# shanghaishi      503
# hangzhou         487
# Name: WORK_CITY, dtype: int64

# %%
df['WORK_COUNTRY'].value_counts().head(20)
# Out:
# CN    57748
# HK      991
# JP      875
# KR      790
# US      575
# TW      281
# SG      281
# AU      271
# MY      161
# PH      137
# FR      102
# ID       82
# TH       64
# CA       54
# NL       49
# DE       46
# VN       45
# BE       41
# VT       30
# MO       29
# Name: WORK_COUNTRY, dtype: int64

# %% [markdown]
# customer mayoritas merupakan warga negara china

# %%
# correlation analysis
plt.figure(figsize = (20,20))
corr = df.describe().columns.tolist()
df_corr = df[corr]
correlation = df_corr.corr()
sns.heatmap(correlation, cmap = "GnBu", annot = True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ada beberapa kolom yang memiliki korelasi kuat. Dapat didrop karena bersifat redundant

# %%
corr_matrix = df.corr().abs()
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))
to_drop_hicorr = [column for column in upper.columns if any(upper[column] > 0.7)]

# %%
to_drop_hicorr
# Out:
# ['BP_SUM', 'SUM_YR_1', 'SUM_YR_2', 'SEG_KM_SUM', 'MAX_INTERVAL', 'Points_Sum']

# %%
df.drop(to_drop_hicorr, axis=1, inplace=True)

# %%
# correlation analysis
plt.figure(figsize = (20,20))
corr = df.describe().columns.tolist()
df_corr = df[corr]
correlation = df_corr.corr()
sns.heatmap(correlation, cmap = "GnBu", annot = True)
# Out:
# <AxesSubplot:>

# %%
    for j in range (0,len(numeric)):
        num = numeric[j]
        sns.kdeplot(x=df[num])
        plt.figure(figsize=(3,3))
        plt.show()

# %% [markdown]
# **Data Insight**
#
# 1. distribusi kolom rata-rata memiliki skew positive yang ekstrim

# %%
    for j in range (0,len(numeric)):
        num = numeric[j]
        sns.boxplot(y=df[num])
        plt.figure(figsize=(3,3))
        plt.show()

# %% [markdown]
# banyak kolom yang memiliki outlier ekstrim

# %%
df.shape[0]
# Out:
# 62988

# %%
(df['WORK_PROVINCE'].value_counts()/df.shape[0]*100)
# Out:
# guangdong        27.797358
# beijing          12.723058
# shanghai          7.934845
# liaoning          6.639360
# xinjiang          3.988061
#                    ...
# YAMAGUCHI-KEN     0.001588
# AICHIKEN          0.001588
# SOUTU HOLLAND     0.001588
# xinxixian         0.001588
# JAWATIMUR         0.001588
# Name: WORK_PROVINCE, Length: 1165, dtype: float64

# %%
(df['WORK_CITY'].value_counts()/df.shape[0]*100)
# Out:
# guangzhou    14.901251
# beijing      12.454753
# shanghai      7.939608
# shenzhen      5.723312
# dalian        3.141868
#                ...
# KASUGAI       0.001588
# hainan        0.001588
# xinxishi      0.001588
# KA            0.001588
# lingshui      0.001588
# Name: WORK_CITY, Length: 3234, dtype: float64

# %%
(df['WORK_COUNTRY'].value_counts()/df.shape[0]*100)
# Out:
# CN    91.680955
# HK     1.573316
# JP     1.389153
# KR     1.254207
# US     0.912872
#         ...
# CD     0.001588
# BI     0.001588
# CM     0.001588
# FL     0.001588
# GL     0.001588
# Name: WORK_COUNTRY, Length: 118, dtype: float64

# %% [markdown]
# customer mayoritas merupakan warga negara china

# %%
# correlation analysis
plt.figure(figsize = (20,20))
corr = df.describe().columns.tolist()
df_corr = df[corr]
correlation = df_corr.corr()
sns.heatmap(correlation, cmap = "GnBu", annot = True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ada beberapa kolom yang memiliki korelasi kuat. Dapat didrop karena bersifat redundant

# %%
corr_matrix = df.corr().abs()
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))
to_drop_hicorr = [column for column in upper.columns if any(upper[column] > 0.7)]

# %%
to_drop_hicorr
# Out:
# ['BP_SUM', 'SUM_YR_1', 'SUM_YR_2', 'SEG_KM_SUM', 'MAX_INTERVAL', 'Points_Sum']

# %%
df.drop(to_drop_hicorr, axis=1, inplace=True)

# %%
# correlation analysis
plt.figure(figsize = (20,20))
corr = df.describe().columns.tolist()
df_corr = df[corr]
correlation = df_corr.corr()
sns.heatmap(correlation, cmap = "GnBu", annot = True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# ## High Cardinality

# %%
from collections import Counter
def cumulatively_categorise(column,threshold=0.8,return_categories_list=True):
  #Find the threshold value using the percentage and number of instances in the column
  threshold_value=int(threshold*len(column))
  #Initialise an empty list for our new minimised categories
  categories_list=[]
  #Initialise a variable to calculate the sum of frequencies
  s=0
  #Create a counter dictionary of the form unique_value: frequency
  counts=Counter(column)

  #Loop through the category name and its corresponding frequency after sorting the categories by descending order of frequency
  for i,j in counts.most_common():
    #Add the frequency to the global sum
    s+=dict(counts)[i]
    #Append the category name to the list
    categories_list.append(i)
    #Check if the global sum has reached the threshold value, if so break the loop
    if s>=threshold_value:
      break
  #Append the category Other to the list
  categories_list.append('Other')

  #Replace all instances not in our new categories by Other  
  new_column=column.apply(lambda x: x if x in categories_list else 'Other')

  #Return transformed column and unique values if return_categories=True
  if(return_categories_list):
    return new_column,categories_list
  #Return only the transformed column if return_categories=False
  else:
    return new_column

# %%
df[cat].describe()
# Out:
#        GENDER WORK_PROVINCE WORK_COUNTRY  WORK_CITY
# count   62985         59740        62962      60719
# unique      2          1165          118       3234
# top      Male     guangdong           CN  guangzhou
# freq    48134         17509        57748       9386

# %%
#Call the function with a default threshold of 90%
df['WORK_PROVINCE_new'],new_category_list=cumulatively_categorise(df['WORK_PROVINCE'],return_categories_list=True)

# %%
#Call the function with a default threshold of 90%
df['WORK_CITY_new'],new_category_list=cumulatively_categorise(df['WORK_CITY'],return_categories_list=True)

# %%
df[['WORK_PROVINCE_new','WORK_CITY_new']].describe()
# Out:
#        WORK_PROVINCE_new WORK_CITY_new
# count              59740         60719
# unique                15            45
# top            guangdong         Other
# freq               17509         12481

# %%
(df['WORK_PROVINCE_new'].value_counts()/df.shape[0]*100)
# Out:
# guangdong        27.797358
# Other            18.713088
# beijing          12.723058
# shanghai          7.934845
# liaoning          6.639360
# xinjiang          3.988061
# jilin             2.894202
# heilongjiang      2.268686
# hubei             2.186131
# henan             1.884486
# jiangsu           1.767003
# zhejiang          1.670159
# .                 1.476472
# hunan             1.471709
# liaoningsheng     1.428844
# Name: WORK_PROVINCE_new, dtype: float64

# %% [markdown]
# ## Feature Engineering

# %%
import datetime as dt
df['YEAR_LOAD_TIME'] = df['LOAD_TIME'].dt.year
df['YEAR_FIRST_FLIGHT_DATE'] = df['FIRST_FLIGHT_DATE'].dt.year
df['CUSTOMER_YEAR'] = df['YEAR_LOAD_TIME'] - df['YEAR_FIRST_FLIGHT_DATE']

# %%
df['CUSTOMER_YEAR'].describe()
# Out:
# count    62988.000000
# mean         3.831539
# std          2.384565
# min         -1.000000
# 25%          2.000000
# 50%          3.000000
# 75%          6.000000
# max        109.000000
# Name: CUSTOMER_YEAR, dtype: float64

# %% [markdown]
# **Data Insight**
#
#     1. Ada kesalahan waktu tahun pengambilan data ada FIRST_FLIGHT_DATE yang 2015 sedangkan data diambil pada tahun 2014
#     2. Ada FIRST_FLIGHT_DATE pada tahun 1905

# %%
df['CUSTOMER_YEAR'].unique()
# Out:
# array([  6,   7,   5,   8,   4,   3,  10,   9,   2,   1,   0,  -1, 109],
#       dtype=int64)

# %%
df['YEAR_FIRST_FLIGHT_DATE'].unique()
# Out:
# array([2008, 2007, 2009, 2006, 2010, 2011, 2004, 2005, 2012, 2013, 2014,
#        2015, 1905], dtype=int64)

# %%
df['YEAR_FIRST_FLIGHT_DATE'] = df['YEAR_FIRST_FLIGHT_DATE'].replace(1905,2005)

# %% [markdown]
# 1905 kemungkinan kesalahan input dari 2005

# %%
df['CUSTOMER_YEAR'] = df['CUSTOMER_YEAR'].replace({-1:0,109:10})

# %%
df['CUSTOMER_YEAR'].describe()
# Out:
# count    62988.000000
# mean         3.828459
# std          2.309892
# min          0.000000
# 25%          2.000000
# 50%          3.000000
# 75%          6.000000
# max         10.000000
# Name: CUSTOMER_YEAR, dtype: float64

# %%
df['CLV'] = (df['SUM_YR_1']*df['FLIGHT_COUNT'])/df['CUSTOMER_YEAR']

# %%
df['CLV'].value_counts()
# Out:
# 0.000000        9449
# 1920.000000       72
# 1400.000000       71
# 1050.000000       60
# 1280.000000       54
#                 ...
# 32212.500000       1
# 66339.666667       1
# 84967.500000       1
# 47845.166667       1
# 77.777778          1
# Name: CLV, Length: 34645, dtype: int64

# %%
df.dropna(subset=['CLV']).shape[0]/df.shape[0]*100
# Out:
# 98.38540674414175

# %% [markdown]
# ## Feature Selection

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62988 entries, 0 to 62987
# Data columns (total 27 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   MEMBER_NO               62988 non-null  int64
#  1   FFP_DATE                62988 non-null  datetime64[ns]
#  2   FIRST_FLIGHT_DATE       62988 non-null  datetime64[ns]
#  3   GENDER                  62985 non-null  object
#  4   FFP_TIER                62988 non-null  int64
#  5   WORK_CITY               60719 non-null  object
#  6   WORK_PROVINCE           59740 non-null  object
#  7   WORK_COUNTRY            62962 non-null  object
#  8   AGE                     62988 non-null  float64
#  9   LOAD_TIME               62988 non-null  datetime64[ns]
#  10  FLIGHT_COUNT            62988 non-null  int64
#  11  BP_SUM                  62988 non-null  int64
#  12  SUM_YR_1                62437 non-null  float64
#  13  SUM_YR_2                62850 non-null  float64
#  14  SEG_KM_SUM              62988 non-null  int64
#  15  LAST_FLIGHT_DATE        62988 non-null  datetime64[ns]
#  16  LAST_TO_END             62988 non-null  int64
#  17  AVG_INTERVAL            62988 non-null  float64
#  18  MAX_INTERVAL            62988 non-null  int64
#  19  EXCHANGE_COUNT          62988 non-null  int64
#  20  avg_discount            62988 non-null  float64
#  21  Points_Sum              62988 non-null  int64
#  22  Point_NotFlight         62988 non-null  int64
#  23  YEAR_LOAD_TIME          62988 non-null  int64
#  24  YEAR_FIRST_FLIGHT_DATE  62988 non-null  int64
#  25  CUSTOMER_YEAR           62988 non-null  int64
#  26  CLV                     61971 non-null  float64
# dtypes: datetime64[ns](4), float64(6), int64(13), object(4)
# memory usage: 13.0+ MB

# %%
preprocessing(df)
# Out:
#                   Number of unique values  Percent of Null(%) Number of Null  \
# Variable
# MEMBER_NO                           62988            0.000000              0
# FFP_DATE                             3068            0.000000              0
# FIRST_FLIGHT_DATE                    3406            0.000000              0
# GENDER                                  2            0.004763              3
# FFP_TIER                                3            0.000000              0
# WORK_CITY                            3234            3.602273           2269
# WORK_PROVINCE                        1165            5.156538           3248
# WORK_COUNTRY                          118            0.041278             26
# AGE                                    84            0.666794            420
# LOAD_TIME                               1            0.000000              0
# FLIGHT_COUNT                          153            0.000000              0
# BP_SUM                              23449            0.000000              0
# SUM_YR_1                            15828            0.874770            551
# SUM_YR_2                            16767            0.219089            138
# SEG_KM_SUM                          29081            0.000000              0
# LAST_FLIGHT_DATE                      731            0.000000              0
# LAST_TO_END                           731            0.000000              0
# AVG_INTERVAL                        10706            0.000000              0
# MAX_INTERVAL                          706            0.000000              0
# EXCHANGE_COUNT                         28            0.000000              0
# avg_discount                        54179            0.000000              0
# Points_Sum                          25062            0.000000              0
# Point_NotFlight                        99            0.000000              0
#
#                       Type                                             Values
# Variable
# MEMBER_NO            int64  [54993, 28065, 55106, 21189, 39546, 56972, 449...
# FFP_DATE            object  [11/2/2006, 2/19/2007, 2/1/2007, 8/22/2008, 4/...
# FIRST_FLIGHT_DATE   object  [12/24/2008, 8/3/2007, 8/30/2007, 8/23/2008, 4...
# GENDER              object                                [Male, Female, nan]
# FFP_TIER             int64                                          [6, 5, 4]
# WORK_CITY           object  [., nan, Los Angeles, guiyang, guangzhou, wulu...
# WORK_PROVINCE       object  [beijing, CA, guizhou, guangdong, xinjiang, zh...
# WORK_COUNTRY        object  [CN, US, FR, AN, JP, HK, MY, AU, NL, MX, CA, K...
# AGE                float64  [31.0, 42.0, 40.0, 64.0, 48.0, 46.0, 50.0, 43....
# LOAD_TIME           object                                        [3/31/2014]
# FLIGHT_COUNT         int64  [210, 140, 135, 23, 152, 92, 101, 73, 56, 64, ...
# BP_SUM               int64  [505308, 362480, 351159, 337314, 273844, 31333...
# SUM_YR_1           float64  [239560.0, 171483.0, 163618.0, 116350.0, 12456...
# SUM_YR_2           float64  [234188.0, 167434.0, 164982.0, 125500.0, 13070...
# SEG_KM_SUM           int64  [580717, 293678, 283712, 281336, 309928, 29458...
# LAST_FLIGHT_DATE    object  [3/31/2014, 3/25/2014, 3/21/2014, 12/26/2013, ...
# LAST_TO_END          int64  [1, 7, 11, 97, 5, 79, 3, 6, 15, 22, 67, 2, 65,...
# AVG_INTERVAL       float64  [3.483253589, 5.194244604, 5.298507463, 27.863...
# MAX_INTERVAL         int64  [18, 17, 73, 47, 52, 28, 45, 94, 95, 42, 112, ...
# EXCHANGE_COUNT       int64  [34, 29, 20, 11, 27, 10, 7, 5, 13, 1, 15, 3, 1...
# avg_discount       float64  [0.961639043, 1.25231444, 1.254675516, 1.09086...
# Points_Sum           int64  [619760, 415768, 406361, 372204, 338813, 34312...
# Point_NotFlight      int64  [50, 33, 26, 12, 39, 15, 29, 14, 7, 16, 3, 66,...

# %% [markdown]
# Fitur yang akan dipakai sebagai clustering:
#
# Demografi :
#
#     1. AGE
#     2. GENDER
#
# Behavioral :
#
#     1. CLV (Customer Lifetime Value)
#     2. FFP_TIER
#     3. AVG_INTERVAL
#     4. Points_Sum

# %% [markdown]
# ## Handling Missing Value

# %%
df_selected = df[['AGE','GENDER','FFP_TIER','AVG_INTERVAL','Points_Sum','CLV','CUSTOMER_YEAR','SUM_YR_1']]

# %%
df_selected = df_selected.dropna(subset=['CLV'])

# %%
df_selected = df_selected[df_selected['CLV']>0]

# %%
df_selected.isnull().sum()
# Out:
# AGE              0
# GENDER           3
# FFP_TIER         0
# AVG_INTERVAL     0
# Points_Sum       0
# CLV              0
# CUSTOMER_YEAR    0
# SUM_YR_1         0
# dtype: int64

# %%
sns.scatterplot(x='AGE',y='YEAR_FIRST_FLIGHT_DATE',data=df)
# Out:
# <AxesSubplot:xlabel='AGE', ylabel='YEAR_FIRST_FLIGHT_DATE'>

# %%
sns.scatterplot(x='AGE',y='CUSTOMER_YEAR',data=df)
# Out:
# <AxesSubplot:xlabel='AGE', ylabel='CUSTOMER_YEAR'>

# %%
sns.scatterplot(x='AGE',y='CLV',data=df)
# Out:
# <AxesSubplot:xlabel='AGE', ylabel='CLV'>

# %%
df_selected[df_selected.isna().any(axis=1)]
# Out:
#         AGE GENDER  FFP_TIER  AVG_INTERVAL  Points_Sum            CLV  \
# 271    61.0    NaN         6     43.000000      159060  129922.500000
# 22471  43.0    NaN         4     61.285714       12220   53040.000000
# 42565  62.0    NaN         4     16.250000        2982    7441.666667
#
#        CUSTOMER_YEAR  SUM_YR_1
# 271                4   30570.0
# 22471              1    6630.0
# 42565              3    4465.0

# %%
sns.kdeplot(df_selected['AGE'])
# Out:
# <AxesSubplot:xlabel='AGE', ylabel='Density'>

# %% [markdown]
# cenderung untuk skew positif tapi tidak ekstrim

# %%
df_selected['AGE'] = df_selected['AGE'].fillna(df_selected['AGE'].median())

# %%
df_selected['GENDER'] = df_selected['GENDER'].replace(np.nan,'Male')

# %%
df_selected.isnull().sum()
# Out:
# AGE              0
# GENDER           0
# FFP_TIER         0
# AVG_INTERVAL     0
# Points_Sum       0
# CLV              0
# CUSTOMER_YEAR    0
# SUM_YR_1         0
# dtype: int64

# %%
df_selected['GENDER'] = df_selected['GENDER'].replace({'Male':1,'Female':0})

# %% [markdown]
# # Clustering

# %%
X = df_selected

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit_transform(X)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\MUHAMM~1\AppData\Local\Temp/ipykernel_588/86038788.py in <module>
#       1 from sklearn.preprocessing import StandardScaler
#       2 scaler = StandardScaler()
# ----> 3 scaler.fit_transform(X)
#
# ~\anaconda3\lib\site-packages\sklearn\base.py in fit_transform(self, X, y, **fit_params)
#     865         if y is None:
#     866             # fit method of arity 1 (unsupervised transformation)
# --> 867             return self.fit(X, **fit_params).transform(X)
#     868         else:
#     869             # fit method of arity 2 (supervised transformation)
#
# ~\anaconda3\lib\site-packages\sklearn\preprocessing\_data.py in fit(self, X, y, sample_weight)
#     807         # Reset internal state before fitting
#     808         self._reset()
# --> 809         return self.partial_fit(X, y, sample_weight)
#     810
#     811     def partial_fit(self, X, y=None, sample_weight=None):
#
# ~\anaconda3\lib\site-packages\sklearn\preprocessing\_data.py in partial_fit(self, X, y, sample_weight)
#     842         """
#     843         first_call = not hasattr(self, "n_samples_seen_")
# --> 844         X = self._validate_data(
#     845             X,
#     846             accept_sparse=("csr", "csc"),
#
# ~\anaconda3\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     575             raise ValueError("Validation should be done on X, y or both.")
#     576         elif not no_val_X and no_val_y:
# --> 577             X = check_array(X, input_name="X", **check_params)
#     578             out = X
#     579         elif no_val_X and not no_val_y:
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     897
#     898         if force_all_finite:
# --> 899             _assert_all_finite(
#     900                 array,
#     901                 input_name=input_name,
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in _assert_all_finite(X, allow_nan, msg_dtype, estimator_name, input_name)
#     144                     "#estimators-that-handle-nan-values"
#     145                 )
# --> 146             raise ValueError(msg_err)
#     147
#     148     # for object dtype data, we only check for NaNs (GH-13254)
#
# ValueError: Input X contains infinity or a value too large for dtype('float64').

# %%
from sklearn.cluster import KMeans, DBSCAN
w = []
K = range(1,10)
for k in K:
    kmeanModel = KMeans(n_clusters=k)
    kmeanModel.fit(X)
    w.append(kmeanModel.inertia_)

plt.figure(figsize=(16,8))
plt.plot(K, w)
plt.xlabel('Number of clusters')
plt.ylabel('Distortion')
plt.title('The Elbow Method showing the optimal number of clusters (k)')

plt.show()
