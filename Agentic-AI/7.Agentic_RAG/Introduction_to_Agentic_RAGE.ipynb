# %% [markdown]
# # Agentic RAG
#
# Agentic RAG is framework that enhance traditional RAG system by incorporatting intelligent Agents to handle complex task and make decisions dynamically

# %% [markdown]
# **Traditional LLM**

# %% [markdown]
# ![image.png](attachment:image.png)
